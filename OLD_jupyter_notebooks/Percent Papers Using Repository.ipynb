# %%
#######################################################
#######################################################
##
## This notebook creates a barchart 
## showing the percentage of papers per journal
## that interact with any kind of sequence repository.
##
#######################################################
#######################################################

# %%
# import required modules
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd
import seaborn as sns

# %%
# import data
df = pd.read_csv('repoPctStats.csv')
df
# Out:
#                                            journalName  totalPapers  \
# 0                                            3_Biotech          636
# 1                                         3D_Print_Med           37
# 2                                               AAPS_J           56
# 3                                          Acad_Pathol          134
# 4                                         Acc_Chem_Res          138
# 5                            ACS_Appl_Mater_Interfaces          278
# 6                                 ACS_Biomater_Sci_Eng           47
# 7                                         ACS_Cent_Sci          793
# 8                                        ACS_Chem_Biol          351
# 9                                    ACS_Chem_Neurosci          102
# 10                                      ACS_Infect_Dis           61
# 11                                            ACS_Nano          441
# 12                                           ACS_Omega          989
# 13                                            ACS_Sens           22
# 14                                      ACS_Synth_Biol          107
# 15                 Acta_Biochim_Biophys_Sin__Shanghai_            7
# 16                                       Acta_Biomater           50
# 17                                       Acta_Cir_Bras           47
# 18                 Acta_Crystallogr_D_Biol_Crystallogr          504
# 19                      Acta_Crystallogr_D_Struct_Biol          213
# 20               Acta_Crystallogr_F_Struct_Biol_Commun          172
# 21    Acta_Crystallogr_Sect_F_Struct_Biol_Cryst_Commun          242
# 22                                       Acta_Diabetol          105
# 23                             Acta_Histochem_Cytochem          331
# 24                                       Acta_Med_Litu           80
# 25                                        Acta_Naturae          471
# 26                                    Acta_Neuropathol          427
# 27                             Acta_Neuropathol_Commun          807
# 28                                     Acta_Ophthalmol           87
# 29                                         Acta_Orthop         1303
# ...                                                ...          ...
# 2543                                World_J_Clin_Oncol          105
# 2544                                  World_J_Diabetes          142
# 2545                                World_J_Emerg_Surg          659
# 2546                             World_J_Gastroenterol         1973
# 2547                        World_J_Gastrointest_Oncol          181
# 2548               World_J_Gastrointest_Pharmacol_Ther           56
# 2549                                   World_J_Hepatol          369
# 2550                      World_J_Microbiol_Biotechnol           76
# 2551                                     World_J_Oncol          391
# 2552           World_J_Otorhinolaryngol_Head_Neck_Surg          146
# 2553                                World_J_Plast_Surg          316
# 2554                                World_J_Stem_Cells           80
# 2555                                      World_J_Surg          329
# 2556                                World_J_Surg_Oncol         3170
# 2557                                      World_J_Urol          149
# 2558                                     World_J_Virol           17
# 2559                                              Worm          120
# 2560                               Xenotransplantation           10
# 2561                                   Yale_J_Biol_Med         7736
# 2562                                  Yearb_Med_Inform           38
# 2563                                             Yeast           88
# 2564                                      Yonsei_Med_J         2662
# 2565                                         Zdr_Varst          159
# 2566                                         Zebrafish           25
# 2567                                          Zoo_Biol            2
# 2568                                           Zookeys         4457
# 2569                                   Zool_J_Linn_Soc            9
# 2570                                   Zoological_Lett          136
# 2571                                          Zool_Res          117
# 2572                                            Zygote            5
#
#       repoPapers  pctRepoPapers
# 0             32       5.031450
# 1              1       2.702700
# 2              2       3.571430
# 3              2       1.492540
# 4              1       0.724638
# 5              2       0.719424
# 6              1       2.127660
# 7              2       0.252207
# 8             13       3.703700
# 9              1       0.980392
# 10             6       9.836070
# 11            10       2.267570
# 12            17       1.718910
# 13             1       4.545450
# 14             7       6.542060
# 15             0       0.000000
# 16             2       4.000000
# 17             1       2.127660
# 18            14       2.777780
# 19             3       1.408450
# 20            20      11.627900
# 21            25      10.330600
# 22             1       0.952381
# 23            12       3.625380
# 24             1       1.250000
# 25            34       7.218680
# 26            49      11.475400
# 27            95      11.772000
# 28             1       1.149430
# 29             5       0.383730
# ...          ...            ...
# 2543           5       4.761900
# 2544           1       0.704225
# 2545           1       0.151745
# 2546          92       4.662950
# 2547          12       6.629830
# 2548           1       1.785710
# 2549           4       1.084010
# 2550           7       9.210530
# 2551           3       0.767263
# 2552           2       1.369860
# 2553           1       0.316456
# 2554           3       3.750000
# 2555           2       0.607903
# 2556          51       1.608830
# 2557           3       2.013420
# 2558           1       5.882350
# 2559           2       1.666670
# 2560           4      40.000000
# 2561           3       0.038780
# 2562           1       2.631580
# 2563           5       5.681820
# 2564          31       1.164540
# 2565           1       0.628931
# 2566           2       8.000000
# 2567           1      50.000000
# 2568          67       1.503250
# 2569           1      11.111100
# 2570          15      11.029400
# 2571           3       2.564100
# 2572           1      20.000000
#
# [2573 rows x 4 columns]

# %%
# temp_df = df.sort_values(['pctRepoPapers'], ascending=False).reset_index(drop=True)
# temp_df

# %%
# sort by total number papers
sorted_df = df.sort_values(['totalPapers'], ascending=False).reset_index(drop=True)

# remove rows with 0% repo mentions
sorted_df = sorted_df[sorted_df.pctRepoPapers != 0]

# take rows with highest totals
CUTOFF = 500
mini_df = sorted_df.iloc[list(range(CUTOFF))]
mini_df

# sum the rest into an "other" column
ind = list(range(CUTOFF, len(sorted_df)))
otherRow = sorted_df.iloc[ind].sum() 
otherRow['journalName'] = "Other"
otherRow['pctRepoPapers'] = otherRow['repoPapers'] / otherRow['totalPapers'] * 100

# add "other" to the dataframe
mini_df = mini_df.append(otherRow.to_frame().transpose(), ignore_index = True)

# sort by percentage
mini_df = mini_df.sort_values(['pctRepoPapers'], ascending=False).reset_index(drop=True)

# %%
# plot the figure

# make the colors look nice
sns.set(style='whitegrid')

# create axes object
plt.figure(figsize=(90,20))
plt.xticks(rotation=90)
ax = sns.barplot(x='journalName', y='pctRepoPapers', data=mini_df)
sns.despine()

# add axis labels
ax.set_xlabel("Journal", fontsize=70)
ax.set_ylabel("Percent Mentioning a Repository", fontsize=70)

# get figure objects
fig = ax.get_figure()

# save to .png file
fig.savefig('pct_papers_mentioning.png', dpi = 200, bbox_inches = 'tight')
