# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd

import seaborn as sns

dfSRA = pd.read_csv('sraReuseCounts.csv')
dfGEO = pd.read_csv('geoReuseCounts.csv')
dfSRA
# Out:
#              id  reuseCount
# 0     DRA000001           1
# 1     DRA000010           1
# 2     DRA000030           0
# 3     DRA000156           0
# 4     DRA000159           0
# 5     DRA000169           0
# 6     DRA000172           0
# 7     DRA000219           0
# 8     DRA000221           0
# 9     DRA000224           0
# 10    DRA000273           0
# 11    DRA000275           0
# 12    DRA000363           0
# 13    DRA000384           1
# 14    DRA000390           0
# 15    DRA000430           0
# 16    DRA000436           0
# 17    DRA000438           0
# 18    DRA000443           0
# 19    DRA000446           0
# 20    DRA000455           0
# 21    DRA000457           0
# 22    DRA000475           0
# 23    DRA000525           0
# 24    DRA000527           0
# 25    DRA000552           0
# 26    DRA000555           0
# 27    DRA000557           0
# 28    DRA000561           0
# 29    DRA000563           0
# ...         ...         ...
# 8878  SRX895868           0
# ...

# %%
sns.set(style='whitegrid')

from scipy.stats import norm
#ax = sns.distplot(dfSRA['reuseCount'], fit=norm, kde=False)

ax = sns.distplot(dfSRA['reuseCount'], kde=False)
#ax2 = sns.distplot(dfGEO['reuseCount'])
graph = ax.get_figure()
graph.savefig('figure.png', dpi=1000, bbox_inches = 'tight')
