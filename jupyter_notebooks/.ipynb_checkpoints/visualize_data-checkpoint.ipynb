# %%
# import required modules
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc
import statistics
from collections import Counter
import matplotlib.dates as mdates

# %%
# import table
mm = pd.read_csv('../data_tables/metadataMatrix_filtered.csv')
mm
# Out:
#               journal      pmc_ID accession converted_accession repository  \
# 0            F1000Res  PMC6008849      GSE6                GSE6        GEO
# 1      Biomed_Res_Int  PMC6413412    GSE129              GSE129        GEO
# 2         Front_Oncol  PMC6611226    GSE447              GSE447        GEO
# 3          BMC_Cancer  PMC6587277    GSE457              GSE457        GEO
# 4        Exp_Ther_Med  PMC6507521   GSM4839              GSE343        GEO
# ...               ...         ...       ...                 ...        ...
# 72405     Dis_Markers  PMC6545767  GSE12452            GSE12452        GEO
# 72406     Dis_Markers  PMC6545767  GSE32323            GSE32323        GEO
# 72407     Dis_Markers  PMC6545767  GSE14407            GSE14407        GEO
# 72408     Dis_Markers  PMC6589307  GSE58539            GSE58539        GEO
# 72409     Dis_Markers  PMC6589301  GSE62254            GSE62254        GEO
#
#                   pmc_date      repository_date  \
# 0      2017-12-31 00:00:00  2001-07-25 00:00:00
# 1      2019-02-26 00:00:00  2003-01-27 00:00:00
# 2      2019-06-28 00:00:00  2003-06-10 00:00:00
# 3      2019-06-20 00:00:00  2003-06-12 00:00:00
# 4      2019-04-23 00:00:00  2003-07-01 00:00:00
# ...                    ...                  ...
# 72405           2019-05-19           2008-08-16
# 72406           2019-05-19           2012-03-20
# 72407           2019-05-19           2009-12-31
# 72408           2019-06-04           2015-03-30
# 72409           2019-06-02           2015-04-17
#
#                                          species                 hardware  \
# 0                            Helicobacter pylori         spotted DNA/cDNA
# 1      Drosophila melanogaster;Drosophila yakuba                      NaN
# 2                                   Mus musculus  spotted oligonucleotide
# 3                       Saccharomyces cerevisiae         spotted DNA/cDNA
# 4                                   Homo sapiens         spotted DNA/cDNA
# ...                                          ...                      ...
# 72405                               Homo sapiens                      NaN
# 72406                               Homo sapiens                      NaN
# 72407                               Homo sapiens  in situ oligonucleotide
# 72408                               Homo sapiens    oligonucleotide beads
# 72409                               Homo sapiens                      NaN
#
#        library_strategy  sraAvg_length  sraBases sraAccess  total_use_count  \
# 0      Expression_Array            NaN       NaN       NaN                1
# 1                   NaN            NaN       NaN       NaN                1
# 2      Expression_Array            NaN       NaN       NaN                1
# 3      Expression_Array            NaN       NaN       NaN                1
# 4      Expression_Array            NaN       NaN       NaN                1
# ...                 ...            ...       ...       ...              ...
# 72405               NaN            NaN       NaN       NaN               16
# 72406               NaN            NaN       NaN       NaN               10
# 72407  Expression_Array            NaN       NaN       NaN               17
# 72408  Expression_Array            NaN       NaN       NaN                2
# 72409               NaN            NaN       NaN       NaN               22
#
#       reuse_role  pub_delay
# 0              G     6003.0
# 1              G     5874.0
# 2              G     5862.0
# 3              G     5852.0
# 4              G     5775.0
# ...          ...        ...
# 72405          R        NaN
# 72406          R        NaN
# 72407          R        NaN
# 72408          R        NaN
# 72409          R        NaN
#
# [72410 rows x 16 columns]

# %% [markdown]
# # Look at each DATASET:

# %%
# how many times is each dataset used?
# take the slice we need from mm
accs = mm[['converted_accession', 'repository', 'total_use_count']].drop_duplicates()
accs['reuse_count'] = accs['total_use_count'] - 1
accs
# Out:
#       converted_accession repository  total_use_count  reuse_count
# 0                    GSE6        GEO                1            0
# 1                  GSE129        GEO                1            0
# 2                  GSE447        GEO                1            0
# 3                  GSE457        GEO                1            0
# 4                  GSE343        GEO                1            0
# ...                   ...        ...              ...          ...
# 68047     GSE9712;GSE9716        GEO                2            1
# 70786   GSE10794;GSE11624        GEO                2            1
# 71086     GSE5206;GSE5261        GEO                2            1
# 71223   GSE36138;GSE36139        GEO                2            1
# 71458             GPL7015        GEO                2            1
#
# [34785 rows x 4 columns]

# %%
# plot distribution of use for each unique dataset, first using a boxplot
# each point is a dataset
fig_dims = (12,8)
fig, ax = plt.subplots(figsize=fig_dims)
datasets_box = sns.boxplot(data = accs, x = 'repository', y = 'reuse_count', ax = ax)
datasets_box.set(yscale = 'log')
# Out:
# [None]

# %%
# visualize reuse distribution with a strip plot (jitter plot)
fig, ax = plt.subplots(figsize=fig_dims)
datasets_strip = sns.stripplot(data = accs, x = 'repository', y = 'reuse_count', ax = ax)
# datasets_strip.set(yscale = 'log')

# %%
# what percentage of datasets are used more than once (re-used at least once)?
accs['wasReused'] = accs['reuse_count'] >= 1
accs = accs.groupby('repository', as_index = False).agg({'wasReused':'mean'})
accs = accs.rename(columns = {'wasReused':'pctReused'})
accs
# Out:
#   repository  pctReused
# 0        GEO   0.234576
# 1        SRA   0.132268

# %%
# plot barplot showing percentage of datasets reused in GEO and SRA
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(data = accs, x = 'repository', y = 'pctReused', ax = ax)
plt.ylim(0,1)
plt.show()

# %%
# define mode function for a list of items with two possible values...
# ...based on which is mentioned more, or 'Both' if score is equal
def getMode(items):
    try:
        r = statistics.mode(items)
    except:
        r = 'Both'
    return r

# %% [markdown]
# # Look at each PAPER:

# %%
paps = mm[['pmc_ID', 'repository', 'reuse_role', 'pmc_date']]
paps = paps.groupby(['pmc_ID'], as_index = False).agg({'repository': lambda x: getMode(x), 
                                                       'reuse_role': lambda r: getMode(r),
                                                       'pmc_date': lambda d: max(d)})
paps
# Out:
#            pmc_ID repository reuse_role             pmc_date
# 0      PMC1079818        GEO          G  2005-03-05 00:00:00
# 1      PMC1082884        GEO          R           2005-03-22
# 2      PMC1088941        GEO          G  2005-02-14 00:00:00
# 3      PMC1088946        GEO          G  2005-02-28 00:00:00
# 4      PMC1090574        GEO          G  2005-04-22 00:00:00
# ...           ...        ...        ...                  ...
# 26131  PMC6639121        SRA          R           2019-07-18
# 26132  PMC6639415        GEO          G  2019-07-18 00:00:00
# 26133  PMC6640630        GEO          G  2019-06-04 00:00:00
# 26134  PMC6646343        GEO          G  2019-07-22 00:00:00
# 26135  PMC6646359        GEO          G  2019-07-22 00:00:00
#
# [26136 rows x 4 columns]

# %%
# how many papers are in GEO, SRA, or both?
rc = Counter(paps['repository'])
repoCounts = pd.DataFrame.from_dict(rc, orient = 'index').reset_index()
repoCounts.columns = ['repository', 'count']
repoCounts
# Out:
#   repository  count
# 0        GEO  15612
# 1        SRA  10194
# 2       Both    330

# %%
# visualize distribution of repositories mentioned by papers
squarefig_dims = (8, 8)
fig1, ax1 = plt.subplots(figsize = squarefig_dims)
ax1.pie(repoCounts['count'], labels = repoCounts['repository'])
ax1.axis('equal')
plt.show()

# %%
# how many papers reuse, generate, or both?
rec = Counter(paps['reuse_role'])
reuseCounts = pd.DataFrame.from_dict(rec, orient = 'index').reset_index()
reuseCounts.columns = ['reuse_role', 'count']
reuseCounts
# Out:
#   reuse_role  count
# 0          G  19534
# 1          R   5292
# 2       Both   1310

# %%
# visualize reuse distribution
fig2, ax2 = plt.subplots(figsize = squarefig_dims)
ax2.pie(reuseCounts['count'], labels = reuseCounts['reuse_role'])
ax2.axis('equal')
plt.show()

# %%
paps.loc[paps['pmc_date'] == 'Both']
# Out:
# Empty DataFrame
# Columns: [pmc_ID, repository, reuse_role, pmc_date]
# Index: []

# %%
# visualize reuse and repository distribution across the years
# add year column
fmt = '%Y-%m-%d'
paps.loc[:,'pmc_date'] = pd.to_datetime(paps['pmc_date'], format = fmt)
# paps['year'] = paps['pmc_date'].dt.year
paps
# Out:
#            pmc_ID repository reuse_role   pmc_date
# 0      PMC1079818        GEO          G 2005-03-05
# 1      PMC1082884        GEO          R 2005-03-22
# 2      PMC1088941        GEO          G 2005-02-14
# 3      PMC1088946        GEO          G 2005-02-28
# 4      PMC1090574        GEO          G 2005-04-22
# ...           ...        ...        ...        ...
# 26131  PMC6639121        SRA          R 2019-07-18
# 26132  PMC6639415        GEO          G 2019-07-18
# 26133  PMC6640630        GEO          G 2019-06-04
# 26134  PMC6646343        GEO          G 2019-07-22
# 26135  PMC6646359        GEO          G 2019-07-22
#
# [26136 rows x 4 columns]

# %%
# get repository counts per date
repo_byDate = paps.groupby(['pmc_date', 'repository'])['repository'].count().to_frame(name = 'repo_count').reset_index()

# get reuse counts per date
reuse_byDate = paps.groupby(['pmc_date', 'reuse_role'])['reuse_role'].count().to_frame(name = 'reuse_count').reset_index()

# merge reuse and repository tables
by_date = pd.merge(repo_byDate, reuse_byDate, on = 'pmc_date', how = 'outer')
by_date
# Out:
#         pmc_date repository  repo_count reuse_role  reuse_count
# 0     2002-03-14        GEO           1          G            1
# 1     2002-06-14        GEO           1          G            1
# 2     2002-08-29        GEO           1          G            1
# 3     2002-08-30        GEO           1          G            1
# 4     2003-03-18        GEO           1          G            1
# ...          ...        ...         ...        ...          ...
# 11946 2019-07-18        SRA           2          G            3
# 11947 2019-07-18        SRA           2          R            1
# 11948 2019-07-22        GEO           2          G            2
# 11949 2019-12-31        GEO           3       Both            1
# 11950 2019-12-31        GEO           3          R            2
#
# [11951 rows x 5 columns]

# %%
# plot cumulative distribution of papers mentioning each repository each year

geo_byDate = by_year.loc[by_date['repository'] == 'GEO', :]
sra_byDate = by_year.loc[by_date['repository'] == 'SRA', :]
bothRepo_byDate = by_year.loc[by_date['repository'] == 'Both', :]

n_bins = 100 # what makes sense for this?

fig, ax = plt.subplots(figsize=fig_dims)
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.hist(geo_byDate['pmc_date'], bins = n_bins, cumulative = True, histtype = 'step')
ax.hist(sra_byDate['pmc_date'], bins = n_bins, cumulative = True, histtype = 'step')
ax.hist(bothRepo_byDate['pmc_date'], bins = n_bins, cumulative = True, histtype = 'step')
plt.show()

# %%
# plot cumulative reuse distribution over the years

R_byDate = by_year.loc[by_date['reuse_role'] == 'R', :]
G_byDate = by_year.loc[by_date['reuse_role'] == 'G', :]
bothReuse_byDate = by_year.loc[by_date['reuse_role'] == 'Both', :]

n_bins = 100 # what makes sense for this?

fig, ax = plt.subplots(figsize=fig_dims)
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.hist(R_byDate['pmc_date'], bins = n_bins, cumulative = True, histtype = 'step')
ax.hist(G_byDate['pmc_date'], bins = n_bins, cumulative = True, histtype = 'step')
ax.hist(bothReuse_byDate['pmc_date'], bins = n_bins, cumulative = True, histtype = 'step')

plt.show()

# %%
# remove papers with 'Both' listed for either repository or reuse_role
paps = paps.loc[paps['repository'] != 'Both', :].loc[paps['reuse_role'] != 'Both', :]
paps
# Out:
#            pmc_ID repository reuse_role   pmc_date
# 0      PMC1079818        GEO          G 2005-03-05
# 1      PMC1082884        GEO          R 2005-03-22
# 2      PMC1088941        GEO          G 2005-02-14
# 3      PMC1088946        GEO          G 2005-02-28
# 4      PMC1090574        GEO          G 2005-04-22
# ...           ...        ...        ...        ...
# 26131  PMC6639121        SRA          R 2019-07-18
# 26132  PMC6639415        GEO          G 2019-07-18
# 26133  PMC6640630        GEO          G 2019-06-04
# 26134  PMC6646343        GEO          G 2019-07-22
# 26135  PMC6646359        GEO          G 2019-07-22
#
# [24559 rows x 4 columns]

# %%
# across GEO and SRA, what percentage of papers reuse data?
reuse_pcts = paps
reuse_pcts['is_reuser'] = (reuse_pcts['reuse_role'] == 'R')

reuse_pcts = reuse_pcts.groupby('repository', as_index = False).agg({'is_reuser' : 'mean'})
reuse_pcts = reuse_pcts.rename(columns = {'is_reuser':'pctReusing'})
reuse_pcts
# Out:
#   repository  pctReusing
# 0        GEO    0.272036
# 1        SRA    0.130705

# %%
# plot percentage of papers mentioning each repository that reuse data
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(data = reuse_pcts, x = 'repository', y = 'pctReusing', ax = ax)
plt.ylim(0,1)
plt.show()

# %% [markdown]
# # Look at each FEATURE:

# %%
mm_filt = pd.merge(paps, mm, how = 'left', on = ['pmc_ID', 'repository', 'reuse_role'])
mm_filt
# Out:
#            pmc_ID repository reuse_role pmc_date_x  is_reuser         journal  \
# 0      PMC1079818        GEO          G 2005-03-05      False    BMC_Genomics
# 1      PMC1079818        GEO          G 2005-03-05      False    BMC_Genomics
# 2      PMC1079818        GEO          G 2005-03-05      False    BMC_Genomics
# 3      PMC1082884        GEO          R 2005-03-22       True        BMC_Biol
# 4      PMC1088941        GEO          G 2005-02-14      False     Genome_Biol
# ...           ...        ...        ...        ...        ...             ...
# 61037  PMC6639415        GEO          G 2019-07-18      False  Cell_Death_Dis
# 61038  PMC6639415        GEO          G 2019-07-18      False  Cell_Death_Dis
# 61039  PMC6640630        GEO          G 2019-06-04      False        Cell_Rep
# 61040  PMC6646343        GEO          G 2019-07-22      False  Cell_Death_Dis
# 61041  PMC6646359        GEO          G 2019-07-22      False  Cell_Death_Dis
#
#        accession converted_accession           pmc_date_y  \
# 0        GSM5435              GSE366  2005-03-05 00:00:00
# 1       GSM34767             GSE1939  2005-03-05 00:00:00
# 2       GSM34768             GSE1939  2005-03-05 00:00:00
# 3          GPL25               GSE54           2005-03-22
# 4        GSE2193             GSE2193  2005-02-14 00:00:00
# ...          ...                 ...                  ...
# 61037  GSE123314           GSE123314  2019-07-18 00:00:00
# 61038  GSE123313           GSE123313  2019-07-18 00:00:00
# 61039  GSE124132           GSE124132  2019-06-04 00:00:00
# 61040  GSE125699           GSE125699  2019-07-22 00:00:00
# 61041  GSE126910           GSE126910  2019-07-22 00:00:00
#
#            repository_date                   species  \
# 0      2003-05-06 00:00:00              Mus musculus
# 1      2005-03-15 00:00:00              Mus musculus
# 2      2005-03-15 00:00:00              Mus musculus
# 3               2002-06-19      Arabidopsis thaliana
# 4      2005-02-21 00:00:00              Homo sapiens
# ...                    ...                       ...
# 61037  2018-12-05 00:00:00              Homo sapiens
# 61038  2018-12-05 00:00:00              Homo sapiens
# 61039  2019-05-04 00:00:00  Saccharomyces cerevisiae
# 61040  2019-01-26 00:00:00              Mus musculus
# 61041  2019-06-22 00:00:00              Homo sapiens
#
#                          hardware  library_strategy  sraAvg_length  sraBases  \
# 0                     SAGE NlaIII  Expression_Array            NaN       NaN
# 1                     SAGE NlaIII  Expression_Array            NaN       NaN
# 2                     SAGE NlaIII  Expression_Array            NaN       NaN
# 3                     SAGE NlaIII  Expression_Array            NaN       NaN
# 4                spotted DNA/cDNA  Expression_Array            NaN       NaN
# ...                           ...               ...            ...       ...
# 61037     in situ oligonucleotide  Expression_Array            NaN       NaN
# 61038     in situ oligonucleotide  Expression_Array            NaN       NaN
# 61039  high-throughput sequencing           RNA-Seq            NaN       NaN
# 61040  high-throughput sequencing           RNA-Seq            NaN       NaN
# 61041  high-throughput sequencing           RNA-Seq            NaN       NaN
#
#       sraAccess  total_use_count  pub_delay
# 0           NaN                1      669.0
# 1           NaN                1      -10.0
# 2           NaN                1      -10.0
# 3           NaN                2        NaN
# 4           NaN                2       -7.0
# ...         ...              ...        ...
# 61037       NaN                1      225.0
# 61038       NaN                1      225.0
# 61039       NaN                1       31.0
# 61040       NaN                1      177.0
# 61041       NaN                1       30.0
#
# [61042 rows x 18 columns]

# %%
g = sns.FacetGrid(mm_filt, col = 'repository')
g.map(plt.scatter, 'sraAvg_length', 'is_reuser')
