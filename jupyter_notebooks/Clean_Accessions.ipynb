# %%
# import modules

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd
import seaborn as sns

# %%
# import GEO reference data

# import table with accession, platform, and series
geoAPS = pd.read_csv('../geo_sample.csv')

# import table with datasets IDs
geoDS = pd.read_csv('../geo_series_table.csv', low_memory = False)
geoDS.columns = ['Series', 'Title', 'Series Type', 'Taxonomy', 
                 'Sample Count', 'Datasets', 'Supplementary Types', 
                 'Supplementary Links', 'PubMed ID', 'SRA Accession', 
                 'Contact', 'Release Date']

# add datasets column by merging
allData = pd.merge(geoAPS, geoDS, how = 'outer', on = 'Series')
geoReference = allData[['Series', 'Accession', 'Platform', 'Datasets']]

geoReference
# Out:
#             Series Accession Platform Datasets
# 0           GSE506      GSM1     GPL4      NaN
# 1           GSE506      GSM2     GPL4      NaN
# 2           GSE462      GSM3     GPL5      NaN
# 3           GSE462      GSM4     GPL5      NaN
# 4           GSE462      GSM5     GPL5      NaN
# ...            ...       ...      ...      ...
# 3280011  GSE136775       NaN      NaN      NaN
# 3280012  GSE136776       NaN      NaN      NaN
# 3280013  GSE137458       NaN      NaN      NaN
# 3280014  GSE137562       NaN      NaN      NaN
# 3280015  GSE137563       NaN      NaN      NaN
#
# [3280016 rows x 4 columns]

# %%
# import SRA reference data
sraReference = pd.read_csv('../sraIDfull.csv', error_bad_lines = False, low_memory=False, quoting=3)
sraReference = sraReference[['SRAStudy', 'Run', 'Experiment', 
                             'BioProject', 'Submission', 'Sample']]
sraReference
# Out:
#           SRAStudy         Run  Experiment  BioProject  Submission      Sample
# 0        ERP000767  ERR3550121  ERX3556726   PRJEB2600  ERA2143351  ERS3773255
# 1        ERP000767  ERR3550142  ERX3556747   PRJEB2600  ERA2143351  ERS3773255
# 2        ERP000767  ERR3550147  ERX3556752   PRJEB2600  ERA2143351  ERS3773263
# 3        ERP000767  ERR3550125  ERX3556730   PRJEB2600  ERA2143351  ERS3773263
# 4        ERP000767  ERR3550137  ERX3556742   PRJEB2600  ERA2143351  ERS3773252
# ...            ...         ...         ...         ...         ...         ...
# 7676058  SRP002493   SRR049674   SRX020916         NaN   SRA017695   SRS073299
# 7676059  SRP002493   SRR049675   SRX021028         NaN   SRA017695   SRS073299
# 7676060  SRP002493   SRR049677   SRX021029         NaN   SRA017695   SRS073299
# 7676061  SRP002064   SRR042496   SRX020084  PRJNA46359       DIEGO   SRS011854
# 7676062  SRP002438   SRR043092   SRX020242         NaN          OF   SRS072567
#
# [7676063 rows x 6 columns]

# %%
# import data scraped from PubMed XML files
pmcData = pd.read_csv('../data_tables/preFilterMatrix.csv')
pmcData

# temporary mini dataframe...
# pmcData = pmcData.iloc[141499:144406]
# pmcData
# Out:
#                     journal      pmc_ID    accession
# 0       Alzheimers_Res_Ther  PMC3707052         GSM1
# 1       Alzheimers_Res_Ther  PMC3706879     GSE45534
# 2       Alzheimers_Res_Ther  PMC3706879     GSE45534
# 3       Alzheimers_Res_Ther  PMC3706879     GSE45534
# 4       Alzheimers_Res_Ther  PMC3706879     GSE45534
# ...                     ...         ...          ...
# 144401          Dis_Markers  PMC3834650      GDS1059
# 144402          Dis_Markers  PMC3834650      GDS1059
# 144403          Dis_Markers  PMC3834650         GDS1
# 144404     Case_Rep_Hematol  PMC6462343  PRJNA437812
# 144405     Case_Rep_Hematol  PMC6462343    SRP135146
#
# [144406 rows x 3 columns]

# %%
# define function returning corresponding metadata or Study/Series ID given any information on a dataset
def grabRelated(table, key, key_col, out_col):
    indices = table.index[table[key_col] == key].tolist()
    if(len(indices) > 0):
        allHits = table.loc[indices][[out_col]]
        modeHits = allHits.mode()
        if(modeHits.empty):
            return 'NaN'
        else:
            return modeHits.iloc[0,0]
    else:
        return 'NaN'

# define functions performing QC on accessions, checking if they exist in the references
def sraChecksOut(acc, col):
    if(acc in sraReference[col].tolist()):
        return True
    else:
        return False
    
def geoChecksOut(acc, col):
    if(acc in geoReference[col].tolist()):
        return True
    else:
        return False

# %%
# check every accession against the corresponding reference, and convert to STUDY/SERIES
# add converted accessions to a new list, to be added as a column later

converted_acc = []

for acc in pmcData['accession']:
    style = ''
    # assign a style to the accession, corresponds to column names
    # SRA styles
    if('SRP' in acc or 'ERP' in acc or 'DRP' in acc):
        style = 'SRAStudy'
    elif('SRR' in acc or 'ERR' in acc or 'DRR' in acc):
        style = 'Run'
    elif('SRX' in acc or 'ERX' in acc or 'DRX' in acc):
        style = 'Experiment'
    elif('PRJNA' in acc or 'PRJD' in acc or 'PRJEB' in acc):
        style = 'BioProject'
    elif('SRA' in acc or 'ERA' in acc or 'DRA' in acc):
        style = 'Submission'
    elif('SRS' in acc or 'ERS' in acc or 'DRS' in acc):
        style = 'Sample'
    # GEO styles
    elif('GSE' in acc):
        style = 'Series'
    elif('GSM' in acc):
        style = 'Accession'
    elif('GPL' in acc):
        style = 'Platform'
    elif('GDS' in acc):
        style = 'Datasets'
    else:
        style = ''
        
    # for SRA accessions, check if they exist in the SRA reference
    # ...and add corresponding STUDY ID to new column
    if(style == 'SRAStudy' or style == 'Run' or style == 'Experiment' or 
       style == 'BioProject' or style == 'Submission' or style == 'Sample'):
        if(not sraChecksOut(acc, style)):
            converted_acc.append('NaN')
        else:
            converted_acc.append(grabRelated(sraReference, acc, style, 'SRAStudy'))
    # for GEO accessions, check if they exist in the GEO reference
    # ...and add corresponding SERIES ID to new column
    elif(style == 'Series' or style == 'Accession' or style == 'Platform' or style == 'Datasets'):
        if(not geoChecksOut(acc, style)):
            converted_acc.append('NaN')
        else:
            converted_acc.append(grabRelated(geoReference, acc, style, 'Series'))
    # something doesn't belong, record as missing
    else:
        converted_acc.append('NaN')

# add the converted accession list as a new column in PubMed data table
# pd.set_option('display.min_rows', 50)
pmcData.loc[:,'converted_accession'] = converted_acc
pmcData = pmcData.drop_duplicates()
pmcData
# Out:
#                     journal      pmc_ID    accession  converted_accession
# 0       Alzheimers_Res_Ther  PMC3707052         GSM1               GSE506
# 1       Alzheimers_Res_Ther  PMC3706879     GSE45534             GSE45534
# 5       Alzheimers_Res_Ther  PMC4255636      GSE5281              GSE5281
# 6       Alzheimers_Res_Ther  PMC4731966     GSE67036             GSE67036
# 7       Alzheimers_Res_Ther  PMC4731966      GSE1297              GSE1297
# 8       Alzheimers_Res_Ther  PMC4731966     GSE48350             GSE48350
# 9       Alzheimers_Res_Ther  PMC4731966     GSE36980             GSE36980
# 10      Alzheimers_Res_Ther  PMC4731966     GSE12679             GSE12679
# 11      Alzheimers_Res_Ther  PMC4731966     GSE12293             GSE12293
# 17      Alzheimers_Res_Ther  PMC4731966     GSE46871             GSE46871
# 41      Alzheimers_Res_Ther  PMC5513091     GSE93678             GSE93678
# 42      Alzheimers_Res_Ther  PMC5819208     GSE44772             GSE44772
# 43      Alzheimers_Res_Ther  PMC5819208     GSE44771             GSE44771
# 45      Alzheimers_Res_Ther  PMC6015462     GSE60862             GSE60862
# 46      Alzheimers_Res_Ther  PMC6015462      GSE5281              GSE5281
# 47      Alzheimers_Res_Ther  PMC6015462     GSE29378             GSE29378
# 48      Alzheimers_Res_Ther  PMC6015462     GSE36980             GSE36980
# 49      Alzheimers_Res_Ther  PMC6015462     GSE48350             GSE48350
# 66      Alzheimers_Res_Ther  PMC6015462      GSE9566              GSE9566
# 77              Biol_Direct  PMC2928186      GSE2361              GSE2361
# 78              Biol_Direct  PMC2928186       GSE952               GSE952
# 81              Biol_Direct  PMC1500996         GPL4       GSE14;GSE15309
# 82              Biol_Direct  PMC1634740       GDS422                  NaN
# 83              Biol_Direct  PMC1634740       GDS596                  NaN
# 84              Biol_Direct  PMC1634740       GDS181                GSE96
# ...                     ...         ...          ...                  ...
# 144347          Dis_Markers  PMC6348834     GSE65858             GSE65858
# 144350          Dis_Markers  PMC6341252     GSE16011             GSE16011
# 144354          Dis_Markers  PMC6387694     GSE53897             GSE53897
# 144358          Dis_Markers  PMC6387694      GPL6101             GSE63561
# 144361          Dis_Markers  PMC6476032     GSE19491             GSE19491
# 144362          Dis_Markers  PMC6476032     GSE37250             GSE37250
# 144363          Dis_Markers  PMC6476032     GSE42834             GSE42834
# 144373          Dis_Markers  PMC6481100     GSE10072             GSE10072
# 144374          Dis_Markers  PMC6481100     GSE32863             GSE32863
# 144375          Dis_Markers  PMC6481100     GSE85841             GSE85841
# 144377          Dis_Markers  PMC6481100        GPL96             GSE19301
# 144379          Dis_Markers  PMC6481100      GPL6884             GSE30682
# 144381          Dis_Markers  PMC6481100     GPL20115  GSE115018;GSE115019
# 144388          Dis_Markers  PMC6545767     GSE13597             GSE13597
# 144389          Dis_Markers  PMC6545767     GSE12452             GSE12452
# 144393          Dis_Markers  PMC6545767     GSE32323             GSE32323
# 144394          Dis_Markers  PMC6545767     GSE14407             GSE14407
# 144395          Dis_Markers  PMC6589307     GSE73953             GSE73953
# 144396          Dis_Markers  PMC6589307     GSE58539             GSE58539
# 144397          Dis_Markers  PMC6589307     GSE14795             GSE14795
# 144400          Dis_Markers  PMC6589301     GSE62254             GSE62254
# 144401          Dis_Markers  PMC3834650      GDS1059              GSE2191
# 144403          Dis_Markers  PMC3834650         GDS1                  NaN
# 144404     Case_Rep_Hematol  PMC6462343  PRJNA437812            SRP135146
# 144405     Case_Rep_Hematol  PMC6462343    SRP135146            SRP135146
#
# [78620 rows x 4 columns]

# %%
# save 'checkpoint' to CSV file
# pmcData.to_csv('postFilterMatrix.csv')

# %%
# temporary cell saving time from big loop...

pmcData = pd.read_csv('../data_tables/postFilterMatrix.csv')
pmcData
# Out:
#                    journal      pmc_ID    accession converted_accession
# 0      Alzheimers_Res_Ther  PMC3707052         GSM1              GSE506
# 1      Alzheimers_Res_Ther  PMC3706879     GSE45534            GSE45534
# 2      Alzheimers_Res_Ther  PMC4255636      GSE5281             GSE5281
# 3      Alzheimers_Res_Ther  PMC4731966     GSE67036            GSE67036
# 4      Alzheimers_Res_Ther  PMC4731966      GSE1297             GSE1297
# ...                    ...         ...          ...                 ...
# 78615          Dis_Markers  PMC6589301     GSE62254            GSE62254
# 78616          Dis_Markers  PMC3834650      GDS1059             GSE2191
# 78617          Dis_Markers  PMC3834650         GDS1                 NaN
# 78618     Case_Rep_Hematol  PMC6462343  PRJNA437812           SRP135146
# 78619     Case_Rep_Hematol  PMC6462343    SRP135146           SRP135146
#
# [78620 rows x 4 columns]

# %%
# Add a column tagging each accession as GEO or SRA

repoList = []

for i in pmcData['converted_accession']:
    if(type(i) == str):
        if('GSE' in i):
            repoList.append('GEO')
        elif('SRP' in i or 'ERP' in i or 'DRP' in i):
            repoList.append('SRA')
        else:
            repoList.append('NaN')
    else:
        repoList.append('NaN')
        
pmcData['repository'] = repoList
pmcData
# Out:
#                    journal      pmc_ID    accession converted_accession  \
# 0      Alzheimers_Res_Ther  PMC3707052         GSM1              GSE506
# 1      Alzheimers_Res_Ther  PMC3706879     GSE45534            GSE45534
# 2      Alzheimers_Res_Ther  PMC4255636      GSE5281             GSE5281
# 3      Alzheimers_Res_Ther  PMC4731966     GSE67036            GSE67036
# 4      Alzheimers_Res_Ther  PMC4731966      GSE1297             GSE1297
# ...                    ...         ...          ...                 ...
# 78615          Dis_Markers  PMC6589301     GSE62254            GSE62254
# 78616          Dis_Markers  PMC3834650      GDS1059             GSE2191
# 78617          Dis_Markers  PMC3834650         GDS1                 NaN
# 78618     Case_Rep_Hematol  PMC6462343  PRJNA437812           SRP135146
# 78619     Case_Rep_Hematol  PMC6462343    SRP135146           SRP135146
#
#       repository
# 0            GEO
# 1            GEO
# 2            GEO
# 3            GEO
# 4            GEO
# ...          ...
# 78615        GEO
# 78616        GEO
# 78617        NaN
# 78618        SRA
# 78619        SRA
#
# [78620 rows x 5 columns]

# %%
# import SRA attribute data
# CAUTION: huge file! Time delay on import...

sraAttributes = pd.read_csv('../sra_complete_runs.csv', error_bad_lines = False, low_memory=False)
pd.set_option('display.max_columns', 50)
sraAttributes
# Out:
#                 Run          ReleaseDate             LoadDate     spots  \
# 0        ERR3550121  2019-09-25 19:35:40                  NaN         0
# 1        ERR3550142  2019-09-25 19:35:41                  NaN         0
# 2        ERR3550147  2019-09-25 19:35:41                  NaN         0
# 3        ERR3550125  2019-09-25 19:35:40                  NaN         0
# 4        ERR3550137  2019-09-25 19:35:40                  NaN         0
# ...             ...                  ...                  ...       ...
# 7676058   SRR049674  2010-05-27 09:26:35  2014-05-27 02:57:13  35888370
# 7676059   SRR049675  2010-05-27 09:26:35  2014-05-27 02:58:17  40264881
# 7676060   SRR049677  2010-05-27 09:26:35  2014-05-27 02:58:58  40852259
# 7676061   SRR042496  2010-05-11 15:16:41  2012-01-19 16:52:13     47760
# 7676062   SRR043092  2010-05-10 17:56:13  2012-01-19 16:52:35    162876
#
#               bases  spots_with_mates  avgLength  size_MB AssemblyName  \
# 0                 0                 0          0        0          NaN
# 1                 0                 0          0        0          NaN
# 2                 0                 0          0        0          NaN
# 3                 0                 0          0        0          NaN
# 4                 0                 0          0        0          NaN
# ...             ...               ...        ...      ...          ...
# 7676058  1794418500                 0         50     1504          NaN
# 7676059  2013244050                 0         50     1696          NaN
# 7676060  2042612950                 0         50     1732          NaN
# 7676061    16505980                 0        345       42          NaN
# 7676062    43696870                 0        268       80          NaN
#
#                                              download_path  Experiment  \
# 0                                                      NaN  ERX3556726
# 1                                                      NaN  ERX3556747
# 2                                                      NaN  ERX3556752
# 3                                                      NaN  ERX3556730
# 4                                                      NaN  ERX3556742
# ...                                                    ...         ...
# 7676058  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...   SRX020916
# 7676059  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...   SRX021028
# 7676060  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...   SRX021029
# 7676061  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...   SRX020084
# 7676062  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...   SRX020242
#
#              LibraryName LibraryStrategy LibrarySelection LibrarySource  \
# 0                    NaN             WGS           RANDOM       GENOMIC
# 1                    NaN             WGS           RANDOM       GENOMIC
# 2                    NaN             WGS           RANDOM       GENOMIC
# 3                    NaN             WGS           RANDOM       GENOMIC
# 4                    NaN             WGS           RANDOM       GENOMIC
# ...                  ...             ...              ...           ...
# 7676058       VVWTA 0h A         FL-cDNA           RT-PCR     VIRAL RNA
# 7676059       VVWTA 0.5A         FL-cDNA           RT-PCR     VIRAL RNA
# 7676060       VVWTA 1h A         FL-cDNA           RT-PCR     VIRAL RNA
# 7676061  VirRnaMgMosqCeI           OTHER       RANDOM PCR     VIRAL RNA
# 7676062          All HCV        AMPLICON              PCR     VIRAL RNA
#
#         LibraryLayout  InsertSize  InsertDev   Platform                Model  \
# 0              PAIRED         250        0.0   ILLUMINA  Illumina HiSeq 2000
# 1              PAIRED         250        0.0   ILLUMINA  Illumina HiSeq 2000
# 2              PAIRED         250        0.0   ILLUMINA  Illumina HiSeq 2000
# 3              PAIRED         250        0.0   ILLUMINA  Illumina HiSeq 2000
# 4              PAIRED         250        0.0   ILLUMINA  Illumina HiSeq 2000
# ...               ...         ...        ...        ...                  ...
# 7676058        SINGLE           0        0.0  ABI_SOLID  AB SOLiD System 3.0
# 7676059        SINGLE           0        0.0  ABI_SOLID  AB SOLiD System 3.0
# 7676060        SINGLE           0        0.0  ABI_SOLID  AB SOLiD System 3.0
# 7676061        SINGLE           0        0.0      LS454  454 GS FLX Titanium
# 7676062        SINGLE           0        0.0      LS454           454 GS FLX
#
#           SRAStudy  BioProject Study_Pubmed_id  ProjectID      Sample  \
# 0        ERP000767   PRJEB2600             NaN     204335  ERS3773255
# 1        ERP000767   PRJEB2600             NaN     204335  ERS3773255
# 2        ERP000767   PRJEB2600             NaN     204335  ERS3773263
# 3        ERP000767   PRJEB2600             NaN     204335  ERS3773263
# 4        ERP000767   PRJEB2600             NaN     204335  ERS3773252
# ...            ...         ...             ...        ...         ...
# 7676058  SRP002493         NaN             2.0          0   SRS073299
# 7676059  SRP002493         NaN             2.0          0   SRS073299
# 7676060  SRP002493         NaN             2.0          0   SRS073299
# 7676061  SRP002064  PRJNA46359             2.0      46359   SRS011854
# 7676062  SRP002438         NaN             2.0          0   SRS072567
#
#             BioSample SampleType    TaxID         ScientificName  \
# 0                 NaN     simple        0    Leishmania infantum
# 1                 NaN     simple        0    Leishmania infantum
# 2                 NaN     simple        0    Leishmania donovani
# 3                 NaN     simple        0    Leishmania donovani
# 4                 NaN     simple        0    Leishmania donovani
# ...               ...        ...      ...                    ...
# 7676058  SAMN00013848     simple    10245         Vaccinia virus
# 7676059  SAMN00013848     simple    10245         Vaccinia virus
# 7676060  SAMN00013848     simple    10245         Vaccinia virus
# 7676061  SAMN00012272     simple  1284618  environmental samples
# 7676062  SAMN00012789     simple    11103          Hepacivirus C
#
#                                    SampleName g1k_pop_code source  \
# 0        0c4ac31a-dec5-11e9-ba7b-68b599768938          NaN    NaN
# 1        0c4ac31a-dec5-11e9-ba7b-68b599768938          NaN    NaN
# 2        0e2d3a2c-dec6-11e9-a5d1-68b59976a384          NaN    NaN
# 3        0e2d3a2c-dec6-11e9-a5d1-68b59976a384          NaN    NaN
# 4        188c9a6e-deba-11e9-ba7b-68b599768938          NaN    NaN
# ...                                       ...          ...    ...
# 7676058                                  VACV          NaN    NaN
# 7676059                                  VACV          NaN    NaN
# 7676060                                  VACV          NaN    NaN
# 7676061                       VirRnaMgMosqCeI          NaN    NaN
# 7676062                               all_hcv          NaN    NaN
#
#         g1k_analysis_group Subject_ID  Sex Disease Tumor Affection_Status  \
# 0                      NaN        NaN  NaN     NaN    no              NaN
# 1                      NaN        NaN  NaN     NaN    no              NaN
# 2                      NaN        NaN  NaN     NaN    no              NaN
# 3                      NaN        NaN  NaN     NaN    no              NaN
# 4                      NaN        NaN  NaN     NaN    no              NaN
# ...                    ...        ...  ...     ...   ...              ...
# 7676058                NaN        NaN  NaN     NaN    no              NaN
# 7676059                NaN        NaN  NaN     NaN    no              NaN
# 7676060                NaN        NaN  NaN     NaN    no              NaN
# 7676061                NaN        NaN  NaN     NaN    no              NaN
# 7676062                NaN        NaN  NaN     NaN    no              NaN
#
#         Analyte_Type Histological_Type Body_Site                  CenterName  \
# 0                NaN               NaN       NaN                     UOC-CCG
# 1                NaN               NaN       NaN                     UOC-CCG
# 2                NaN               NaN       NaN                     UOC-CCG
# 3                NaN               NaN       NaN                     UOC-CCG
# 4                NaN               NaN       NaN                     UOC-CCG
# ...              ...               ...       ...                         ...
# 7676058          NaN               NaN       NaN               NIAID-RML-RTS
# 7676059          NaN               NaN       NaN               NIAID-RML-RTS
# 7676060          NaN               NaN       NaN               NIAID-RML-RTS
# 7676061          NaN               NaN       NaN  SAN DIEGO STATE UNIVERSITY
# 7676062          NaN               NaN       NaN  UNIVERSITY OF PENNSYLVANIA
#
#          Submission dbgap_study_accession Consent  \
# 0        ERA2143351                   NaN  public
# 1        ERA2143351                   NaN  public
# 2        ERA2143351                   NaN  public
# 3        ERA2143351                   NaN  public
# 4        ERA2143351                   NaN  public
# ...             ...                   ...     ...
# 7676058   SRA017695                   NaN  public
# 7676059   SRA017695                   NaN  public
# 7676060   SRA017695                   NaN  public
# 7676061   SRA012164                   NaN  public
# 7676062   SRA012580                   NaN  public
#
#                                   RunHash                          ReadHash
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
# ...                                   ...                               ...
# 7676058  1C9EE0CEFAE2352A0321B24EAB64EE18  753ED95CDA0B112FD877F38960613605
# 7676059  9F96F35BE762574A084985FD9C918C28  392587111A738BC44AE8878E649D052A
# 7676060  22DCD0A93DAA207187EF6C6F6A835A55  416EBCA2B1A6AB70E4F778F16C36FCE5
# 7676061  633E95BCDFC18AD9C8B5DEAAFAE4DD3F  00AB1B11657DAE26FFECDAD623148A3C
# 7676062  1D70AED9981C7955082992A1AA787246  7C03FE9A87DE427C72136E8C1CA1781C
#
# [7676063 rows x 47 columns]

# %%
# import GEO attribute data and add Series column

geoAttributes = pd.read_csv('../geo_platforms_table.csv')
geoAttributes.rename(columns={'Accession':'Platform'}, inplace=True)
geoAttributes = pd.merge(geoAttributes, geoReference, how = 'left', on = 'Platform')
geoAttributes
# Out:
#          Platform                                              Title  \
# 0            GPL4                        SAGE:10:NlaIII:Homo sapiens
# 1            GPL4                        SAGE:10:NlaIII:Homo sapiens
# 2            GPL4                        SAGE:10:NlaIII:Homo sapiens
# 3            GPL4                        SAGE:10:NlaIII:Homo sapiens
# 4            GPL4                        SAGE:10:NlaIII:Homo sapiens
# ...           ...                                                ...
# 2961228  GPL27549  Illumina HiSeq 2000 (Escherichia coli str. K-1...
# 2961229  GPL27550            Illumina HiSeq 4000 (Solanum chacoense)
# 2961230  GPL27552  Illumina HiSeq 2500 (Caenorhabditis elegans ,V...
# 2961231  GPL27554       Illumina HiSeq 2000 (Trichoderma atroviride)
# 2961232  GPL27555  Illumina HiSeq 2500 (Caenorhabditis elegans; V...
#
#                          Technology  \
# 0                       SAGE NlaIII
# 1                       SAGE NlaIII
# 2                       SAGE NlaIII
# 3                       SAGE NlaIII
# 4                       SAGE NlaIII
# ...                             ...
# 2961228  high-throughput sequencing
# 2961229  high-throughput sequencing
# 2961230  high-throughput sequencing
# 2961231  high-throughput sequencing
# 2961232  high-throughput sequencing
#
#                                                 Taxonomy  Data Rows  \
# 0                                           Homo sapiens     265577
# 1                                           Homo sapiens     265577
# 2                                           Homo sapiens     265577
# 3                                           Homo sapiens     265577
# 4                                           Homo sapiens     265577
# ...                                                  ...        ...
# 2961228         Escherichia coli str. K-12 substr. DH10B          0
# 2961229                                Solanum chacoense          0
# 2961230  Caenorhabditis elegans ,Vibrio parahaemolyticus          0
# 2961231                           Trichoderma atroviride          0
# 2961232   Caenorhabditis elegans;Vibrio parahaemolyticus          0
#
#          Samples Count  Series Count Contact  Release Date  Series Accession  \
# 0                  580            58     GEO  Sep 28, 2000  GSE506      GSM1
# 1                  580            58     GEO  Sep 28, 2000  GSE506      GSM2
# 2                  580            58     GEO  Sep 28, 2000   GSE10    GSM571
# 3                  580            58     GEO  Sep 28, 2000   GSE10    GSM572
# 4                  580            58     GEO  Sep 28, 2000   GSE10    GSM573
# ...                ...           ...     ...           ...     ...       ...
# 2961228              0             0     GEO  Sep 30, 2019     NaN       NaN
# 2961229              0             0     GEO  Sep 30, 2019     NaN       NaN
# 2961230              0             0     GEO  Sep 30, 2019     NaN       NaN
# 2961231              0             0     GEO  Sep 30, 2019     NaN       NaN
# 2961232              0             0     GEO  Sep 30, 2019     NaN       NaN
#
#         Datasets
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 2961228      NaN
# 2961229      NaN
# 2961230      NaN
# 2961231      NaN
# 2961232      NaN
#
# [2961233 rows x 12 columns]

# %%
# # temporary mini dataframe...
# pmcData = pmcData.iloc[1:100]
# pmcData

# %%
# add column for paper publish date

pmc_dates = pd.read_csv('../data_lists/postFilterDates.txt')

pmcData.loc[:,'pmc_date'] = pmc_dates['date'].tolist()
pmcData
# Out:
#                    journal      pmc_ID    accession converted_accession  \
# 0      Alzheimers_Res_Ther  PMC3707052         GSM1              GSE506
# 1      Alzheimers_Res_Ther  PMC3706879     GSE45534            GSE45534
# 2      Alzheimers_Res_Ther  PMC4255636      GSE5281             GSE5281
# 3      Alzheimers_Res_Ther  PMC4731966     GSE67036            GSE67036
# 4      Alzheimers_Res_Ther  PMC4731966      GSE1297             GSE1297
# ...                    ...         ...          ...                 ...
# 78615          Dis_Markers  PMC6589301     GSE62254            GSE62254
# 78616          Dis_Markers  PMC3834650      GDS1059             GSE2191
# 78617          Dis_Markers  PMC3834650         GDS1                 NaN
# 78618     Case_Rep_Hematol  PMC6462343  PRJNA437812           SRP135146
# 78619     Case_Rep_Hematol  PMC6462343    SRP135146           SRP135146
#
#       repository  pmc_date
# 0            GEO      2013
# 1            GEO      2013
# 2            GEO      2014
# 3            GEO      2016
# 4            GEO      2016
# ...          ...       ...
# 78615        GEO      2019
# 78616        GEO      2013
# 78617        NaN      2013
# 78618        SRA      2019
# 78619        SRA      2019
#
# [78620 rows x 6 columns]

# %%
grabRelated(geoAttributes, 'GSE45534', 'Series', 'Taxonomy')
# Out:
# 'Mus musculus'

# %%
slicedGEOAtt = geoAttributes[['Series', 'Taxonomy']]
slicedGEOAtt.columns = ['converted_accession', 'geoSpecies']
slicedGEOAtt = slicedGEOAtt.drop_duplicates(subset = ['geoSpecies'])

slicedSRAAtt = sraAttributes[['SRAStudy', 'ScientificName']]
slicedSRAAtt.columns = ['converted_accession', 'sraSpecies']
slicedSRAAtt = slicedSRAAtt.drop_duplicates(subset = ['sraSpecies'])

# slicedGEOAtt
# mergedGEO = pd.merge(pmcData, slicedGEOAtt, how = 'left', on = 'converted_accession')
# mergedSRA = pd.merge(mergedGEO, slicedSRAAtt, how = 'left', on = 'converted_accession')

mergedSRA = pd.merge(pmcData, slicedSRAAtt, how = 'left', on = 'converted_accession')

mergedSRA = mergedSRA.drop_duplicates()
mergedSRA
# Out:
#                     journal      pmc_ID    accession converted_accession  \
# 0       Alzheimers_Res_Ther  PMC3707052         GSM1              GSE506
# 1       Alzheimers_Res_Ther  PMC3706879     GSE45534            GSE45534
# 2       Alzheimers_Res_Ther  PMC4255636      GSE5281             GSE5281
# 3       Alzheimers_Res_Ther  PMC4731966     GSE67036            GSE67036
# 4       Alzheimers_Res_Ther  PMC4731966      GSE1297             GSE1297
# ...                     ...         ...          ...                 ...
# 318848          Dis_Markers  PMC6589301     GSE62254            GSE62254
# 318849          Dis_Markers  PMC3834650      GDS1059             GSE2191
# 318850          Dis_Markers  PMC3834650         GDS1                 NaN
# 318851     Case_Rep_Hematol  PMC6462343  PRJNA437812           SRP135146
# 318852     Case_Rep_Hematol  PMC6462343    SRP135146           SRP135146
#
#        repository  pmc_date sraSpecies
# 0             GEO      2013        NaN
# 1             GEO      2013        NaN
# 2             GEO      2014        NaN
# 3             GEO      2016        NaN
# 4             GEO      2016        NaN
# ...           ...       ...        ...
# 318848        GEO      2019        NaN
# 318849        GEO      2013        NaN
# 318850        NaN      2013        NaN
# 318851        SRA      2019        NaN
# 318852        SRA      2019        NaN
#
# [318853 rows x 7 columns]

# %%
mergedGEO = pd.merge(mergedSRA, slicedGEOAtt, how = 'left', on = 'converted_accession')
mergedGEO.dropna(subset = ['converted_accession'])
mergedGEO
# Out:
#                       journal      pmc_ID    accession converted_accession  \
# 0         Alzheimers_Res_Ther  PMC3707052         GSM1              GSE506
# 1         Alzheimers_Res_Ther  PMC3707052         GSM1              GSE506
# 2         Alzheimers_Res_Ther  PMC3706879     GSE45534            GSE45534
# 3         Alzheimers_Res_Ther  PMC3706879     GSE45534            GSE45534
# 4         Alzheimers_Res_Ther  PMC4255636      GSE5281             GSE5281
# ...                       ...         ...          ...                 ...
# 97185616          Dis_Markers  PMC3834650         GDS1                 NaN
# 97185617          Dis_Markers  PMC3834650         GDS1                 NaN
# 97185618          Dis_Markers  PMC3834650         GDS1                 NaN
# 97185619     Case_Rep_Hematol  PMC6462343  PRJNA437812           SRP135146
# 97185620     Case_Rep_Hematol  PMC6462343    SRP135146           SRP135146
#
#          repository  pmc_date            sraSpecies  \
# 0               GEO      2013                   NaN
# 1               GEO      2013                   NaN
# 2               GEO      2013                   NaN
# 3               GEO      2013                   NaN
# 4               GEO      2014                   NaN
# ...             ...       ...                   ...
# 97185616        NaN      2013       soil metagenome
# 97185617        NaN      2013       soil metagenome
# 97185618        NaN      2013       soil metagenome
# 97185619        SRA      2019  human gut metagenome
# 97185620        SRA      2019  human gut metagenome
#
#                                                geoSpecies
# 0                                            Homo sapiens
# 1                                            Homo sapiens
# 2                                            Mus musculus
# 3                                            Mus musculus
# 4                                            Homo sapiens
# ...                                                   ...
# 97185616  Caenorhabditis elegans ,Vibrio parahaemolyticus
# 97185617                           Trichoderma atroviride
# 97185618   Caenorhabditis elegans;Vibrio parahaemolyticus
# 97185619                                              NaN
# 97185620                                              NaN
#
# [97185621 rows x 8 columns]

# %%
mergedGEO = mergedGEO.dropna(subset = ['converted_accession'])
mergedGEO
# Out:
#                       journal      pmc_ID    accession converted_accession  \
# 0         Alzheimers_Res_Ther  PMC3707052         GSM1              GSE506
# 1         Alzheimers_Res_Ther  PMC3707052         GSM1              GSE506
# 2         Alzheimers_Res_Ther  PMC3706879     GSE45534            GSE45534
# 3         Alzheimers_Res_Ther  PMC3706879     GSE45534            GSE45534
# 4         Alzheimers_Res_Ther  PMC4255636      GSE5281             GSE5281
# ...                       ...         ...          ...                 ...
# 97166104          Dis_Markers  PMC3834650      GDS1059             GSE2191
# 97166105          Dis_Markers  PMC3834650      GDS1059             GSE2191
# 97166106          Dis_Markers  PMC3834650      GDS1059             GSE2191
# 97185619     Case_Rep_Hematol  PMC6462343  PRJNA437812           SRP135146
# 97185620     Case_Rep_Hematol  PMC6462343    SRP135146           SRP135146
#
#          repository  pmc_date            sraSpecies    geoSpecies
# 0               GEO      2013                   NaN  Homo sapiens
# 1               GEO      2013                   NaN  Homo sapiens
# 2               GEO      2013                   NaN  Mus musculus
# 3               GEO      2013                   NaN  Mus musculus
# 4               GEO      2014                   NaN  Homo sapiens
# ...             ...       ...                   ...           ...
# 97166104        GEO      2013                   NaN  Homo sapiens
# 97166105        GEO      2013                   NaN  Homo sapiens
# 97166106        GEO      2013                   NaN  Homo sapiens
# 97185619        SRA      2019  human gut metagenome           NaN
# 97185620        SRA      2019  human gut metagenome           NaN
#
# [5108493 rows x 8 columns]

# %%
ds_date = []
hardware = []
lib_type = []
species = []
tput = []
readLength = []
access = []

for acc in pmcData['converted_accession']:
    if(type(acc) == str):
        if('GSE' in acc):
            ds_date.append(grabRelated(geoAttributes, acc, 'Series', 'Release Date'))
            hardware.append(grabRelated(geoAttributes, acc, 'Series', 'Technology'))
            lib_type.append('MISSING')
            species.append(grabRelated(geoAttributes, acc, 'Series', 'Taxonomy'))
            tput.append('MISSING')
            readLength.append('MISSING')
            access.append('MISSING')
        if('SRP' in acc or 'ERP' in acc or 'DRP' in acc):
            ds_date.append(grabRelated(sraAttributes, acc, 'SRAStudy', 'ReleaseDate'))
            hardware.append(grabRelated(sraAttributes, acc, 'SRAStudy', 'Model'))
            lib_type.append(grabRelated(sraAttributes, acc, 'SRAStudy', 'LibraryStrategy'))
            species.append(grabRelated(sraAttributes, acc, 'SRAStudy', 'ScientificName'))
            tput.append(grabRelated(sraAttributes, acc, 'SRAStudy', 'bases'))
            readLength.append(grabRelated(sraAttributes, acc, 'SRAStudy', 'avgLength'))
            access.append(grabRelated(sraAttributes, acc, 'SRAStudy', 'Consent'))
    else:
        ds_date.append('NaN')
        hardware.append('NaN')
        lib_type.append('NaN')
        species.append('NaN')
        tput.append('NaN')
        readLength.append('NaN')
        access.append('NaN')
        
        
# # for reference, amt. of rows in pmcData
# print(len(pmcData['journal']))   

# # amt of items in each potential column
# for i in [ds_date, hardware, lib_type, species, tput, readLength, access]:
#     print(len(i))

pmcData.loc[:,'dataset_date'] = ds_date
pmcData.loc[:,'hardware'] = hardware
pmcData.loc[:,'library_type'] = lib_type
pmcData.loc[:,'species'] = species
pmcData.loc[:,'throughput'] = tput
pmcData.loc[:,'avg_readLength'] = readLength
pmcData.loc[:,'access_restrictions'] = access

pmcData

pmcData.to_csv('pmcFactorMatrix.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-20c6cd4dd3f0> in <module>
#      42 #     print(len(i))
#      43
# ---> 44 pmcData.loc[:,'dataset_date'] = ds_date
#      45 pmcData.loc[:,'hardware'] = hardware
#      46 pmcData.loc[:,'library_type'] = lib_type
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     203             key = com.apply_if_callable(key, self.obj)
#     204         indexer = self._get_setitem_indexer(key)
# --> 205         self._setitem_with_indexer(indexer, value)
#     206
#     207     def _validate_key(self, key, axis: int):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     379                             indexer, self.obj.axes
#     380                         )
# --> 381                         self._setitem_with_indexer(new_indexer, value)
#     382
#     383                         return self.obj
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     545                     if len(labels) != len(value):
#     546                         raise ValueError(
# --> 547                             "Must have equal len keys and value "
#     548                             "when setting with an iterable"
#     549                         )
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
# for reference, amt. of rows in pmcData
print(len(pmcData['journal']))   

# amt of items in each potential column
for i in [ds_date, hardware, lib_type, species, tput, readLength, access]:
    print(len(i))
# Out:
# 78620
# 77730
# 77730
# 77730
# 77730
# 77730
# 77730
# 77730

# %%
# print(pmcData.iloc[77725:77735])

# print(grabRelated(sraAttributes, 'SRP072215', 'SRAStudy', 'ReleaseDate'))

sraAttributes.loc[sraAttributes['SRAStudy'] == 'SRP072215']
# Out:
#                 Run          ReleaseDate             LoadDate     spots  \
# 2483169  SRR3285514  2016-06-03 15:05:20  2016-04-25 10:51:25  15995925
# 2526521  SRR3285788  2016-06-03 15:05:20  2016-03-24 10:25:18  18682170
# 2526522  SRR3285726  2016-06-03 15:05:20  2016-03-24 10:24:13  20594831
# 2526523  SRR3285794  2016-06-03 15:05:20  2016-03-24 10:28:48  21715643
# 2526524  SRR3285619  2016-06-03 15:05:20  2016-03-24 10:30:15  31273523
# 2526525  SRR3457432  2016-06-03 15:05:20  2016-04-27 11:59:52  23242094
# 2526600  SRR3285502  2016-06-03 15:05:20  2016-03-24 10:31:05  44837839
# 2526601  SRR3285505  2016-06-03 15:05:20  2016-03-23 11:38:08  18611330
# 2526602  SRR3285580  2016-06-03 15:05:20  2016-04-25 10:50:05  23242094
# 2526603  SRR3285507  2016-06-03 15:05:20  2016-03-24 12:08:08  21940558
# 2526604  SRR3285508  2016-06-03 15:05:20  2016-03-24 10:34:58  23610388
# 2526605  SRR3285513  2016-06-03 15:05:20  2016-03-24 10:35:23  20601995
# 2526606  SRR3285534  2016-06-03 15:05:20  2016-03-24 10:35:35  22803121
# 2526607  SRR3285517  2016-06-03 15:05:20  2016-03-24 10:18:22  20770595
# 2526608  SRR3285509  2016-06-03 15:05:20  2016-03-24 10:38:56  20598597
# 2526609  SRR3285504  2016-06-03 15:05:20  2016-03-24 10:26:07  17170603
# 2526610  SRR3285510  2016-06-03 15:05:20  2016-03-24 10:20:46  20823734
# 2526611  SRR3285511  2016-06-03 15:05:20  2016-03-24 10:20:21  18691674
# 2526612  SRR3285587  2016-06-03 15:05:20  2016-03-24 10:25:06  17264414
# 2526613  SRR3285600  2016-06-03 15:05:20  2016-03-24 12:04:36  21345403
# 2526614  SRR3285512  2016-06-03 15:05:20  2016-03-24 10:39:23  42532093
#
#                bases  spots_with_mates  avgLength  size_MB AssemblyName  \
# 2483169   4830769350          15995925        302     2633          NaN
# 2526521   5642015340          18682170        302     2182          NaN
# 2526522   6219638962          20594831        302     2403          NaN
# 2526523   6558124186          21715643        302     2563          NaN
# 2526524   9444603946          31273523        302     3433          NaN
# 2526525   7019112388          23242094        302     2683          NaN
# 2526600  13541027378          44837839        302     5630          NaN
# 2526601   5620621660          18611330        302     2149          NaN
# 2526602   7019112388          23242094        302     2683          NaN
# 2526603   6626048516          21940558        302     2540          NaN
# 2526604   7130337176          23610388        302     2730          NaN
# 2526605   6221802490          20601995        302     2483          NaN
# 2526606   6886542542          22803121        302     2660          NaN
# 2526607   6272719690          20770595        302     2393          NaN
# 2526608   6220776294          20598597        302     2385          NaN
# 2526609   5185522106          17170603        302     1993          NaN
# 2526610   6288767668          20823734        302     2424          NaN
# 2526611   5644885548          18691674        302     2238          NaN
# 2526612   5213853028          17264414        302     2040          NaN
# 2526613   6446311706          21345403        302     2481          NaN
# 2526614  12844692086          42532093        302     5335          NaN
#
#                                              download_path  Experiment  \
# 2483169  https://sra-download.ncbi.nlm.nih.gov/traces/s...  SRX1656384
# 2526521  https://sra-download.ncbi.nlm.nih.gov/traces/s...  SRX1656467
# 2526522  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  SRX1656466
# 2526523  https://sra-download.ncbi.nlm.nih.gov/traces/s...  SRX1656468
# 2526524  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  SRX1656455
# 2526525  https://sra-download.ncbi.nlm.nih.gov/traces/s...  SRX1656380
# 2526600  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  SRX1656370
# 2526601  https://sra-download.ncbi.nlm.nih.gov/traces/s...  SRX1656373
# 2526602  https://sra-download.st-va.ncbi.nlm.nih.gov/so...  SRX1656374
# 2526603  https://sra-download.st-va.ncbi.nlm.nih.gov/so...  SRX1656375
# 2526604  https://sra-download.ncbi.nlm.nih.gov/traces/s...  SRX1656376
# 2526605  https://sra-download.ncbi.nlm.nih.gov/traces/s...  SRX1656382
# 2526606  https://sra-download.ncbi.nlm.nih.gov/traces/s...  SRX1656393
# 2526607  https://sra-download.st-va.ncbi.nlm.nih.gov/so...  SRX1656371
# 2526608  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  SRX1656377
# 2526609  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  SRX1656372
# 2526610  https://sra-download.st-va.ncbi.nlm.nih.gov/so...  SRX1656378
# 2526611  https://sra-download.st-va.ncbi.nlm.nih.gov/so...  SRX1656379
# 2526612  https://sra-download.ncbi.nlm.nih.gov/traces/s...  SRX1656422
# 2526613  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  SRX1656437
# 2526614  https://sra-download.ncbi.nlm.nih.gov/traces/s...  SRX1656381
#
#                 LibraryName LibraryStrategy LibrarySelection LibrarySource  \
# 2483169           TM6-lab-1             WGS           RANDOM       GENOMIC
# 2526521     CyO-TM3-24759-1             WGS           RANDOM       GENOMIC
# 2526522      CyO-TM3-3251-1             WGS           RANDOM       GENOMIC
# 2526523     CyO-TM3-38418-1             WGS           RANDOM       GENOMIC
# 2526524       CyO-TM3-504-1             WGS           RANDOM       GENOMIC
# 2526525  CyO-TM3-mp-22239-1             WGS           RANDOM       GENOMIC
# 2526600           TM3-120-1             WGS           RANDOM       GENOMIC
# 2526601          TM3-1614-1             WGS           RANDOM       GENOMIC
# 2526602          TM3-1679-1             WGS           RANDOM       GENOMIC
# 2526603          TM3-2053-1             WGS           RANDOM       GENOMIC
# 2526604          TM3-2098-1             WGS           RANDOM       GENOMIC
# 2526605          TM3-2198-1             WGS           RANDOM       GENOMIC
# 2526606          TM3-2485-1             WGS           RANDOM       GENOMIC
# 2526607           TM3-500-1             WGS           RANDOM       GENOMIC
# 2526608          TM3-5457-1             WGS           RANDOM       GENOMIC
# 2526609           TM3-560-1             WGS           RANDOM       GENOMIC
# 2526610          TM3-8852-1             WGS           RANDOM       GENOMIC
# 2526611          TM3-9013-1             WGS           RANDOM       GENOMIC
# 2526612          TM6B-120-1             WGS           RANDOM       GENOMIC
# 2526613         TM6B-2188-1             WGS           RANDOM       GENOMIC
# 2526614       TM6B-mp-587-1             WGS           RANDOM       GENOMIC
#
#         LibraryLayout  InsertSize  InsertDev  Platform                Model  \
# 2483169        PAIRED           0        0.0  ILLUMINA  Illumina HiSeq 2500
# 2526521        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526522        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526523        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526524        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526525        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526600        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526601        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526602        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526603        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526604        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526605        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526606        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526607        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526608        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526609        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526610        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526611        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526612        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526613        PAIRED           0        0.0  ILLUMINA          NextSeq 500
# 2526614        PAIRED           0        0.0  ILLUMINA          NextSeq 500
#
#           SRAStudy   BioProject Study_Pubmed_id  ProjectID      Sample  \
# 2483169  SRP072215  PRJNA315473             NaN     315473  SRS1356703
# 2526521  SRP072215  PRJNA315473             NaN     315473  SRS1356730
# 2526522  SRP072215  PRJNA315473             NaN     315473  SRS1356709
# 2526523  SRP072215  PRJNA315473             NaN     315473  SRS1356729
# 2526524  SRP072215  PRJNA315473             NaN     315473  SRS1356710
# 2526525  SRP072215  PRJNA315473             NaN     315473  SRS1356700
# 2526600  SRP072215  PRJNA315473             NaN     315473  SRS1356698
# 2526601  SRP072215  PRJNA315473             NaN     315473  SRS1356691
# 2526602  SRP072215  PRJNA315473             NaN     315473  SRS1356696
# 2526603  SRP072215  PRJNA315473             NaN     315473  SRS1356695
# 2526604  SRP072215  PRJNA315473             NaN     315473  SRS1356694
# 2526605  SRP072215  PRJNA315473             NaN     315473  SRS1356708
# 2526606  SRP072215  PRJNA315473             NaN     315473  SRS1356707
# 2526607  SRP072215  PRJNA315473             NaN     315473  SRS1356697
# 2526608  SRP072215  PRJNA315473             NaN     315473  SRS1356693
# 2526609  SRP072215  PRJNA315473             NaN     315473  SRS1356692
# 2526610  SRP072215  PRJNA315473             NaN     315473  SRS1356702
# 2526611  SRP072215  PRJNA315473             NaN     315473  SRS1356701
# 2526612  SRP072215  PRJNA315473             NaN     315473  SRS1356706
# 2526613  SRP072215  PRJNA315473             NaN     315473  SRS1356705
# 2526614  SRP072215  PRJNA315473             NaN     315473  SRS1356699
#
#             BioSample SampleType  TaxID           ScientificName  \
# 2483169  SAMN04562534     simple   7227  Drosophila melanogaster
# 2526521  SAMN04562528     simple   7227  Drosophila melanogaster
# 2526522  SAMN04562526     simple   7227  Drosophila melanogaster
# 2526523  SAMN04562529     simple   7227  Drosophila melanogaster
# 2526524  SAMN04562525     simple   7227  Drosophila melanogaster
# 2526525  SAMN04562527     simple   7227  Drosophila melanogaster
# 2526600  SAMN04562513     simple   7227  Drosophila melanogaster
# 2526601  SAMN04562516     simple   7227  Drosophila melanogaster
# 2526602  SAMN04562517     simple   7227  Drosophila melanogaster
# 2526603  SAMN04562518     simple   7227  Drosophila melanogaster
# 2526604  SAMN04562519     simple   7227  Drosophila melanogaster
# 2526605  SAMN04562520     simple   7227  Drosophila melanogaster
# 2526606  SAMN04562521     simple   7227  Drosophila melanogaster
# 2526607  SAMN04562514     simple   7227  Drosophila melanogaster
# 2526608  SAMN04562522     simple   7227  Drosophila melanogaster
# 2526609  SAMN04562515     simple   7227  Drosophila melanogaster
# 2526610  SAMN04562523     simple   7227  Drosophila melanogaster
# 2526611  SAMN04562524     simple   7227  Drosophila melanogaster
# 2526612  SAMN04562531     simple   7227  Drosophila melanogaster
# 2526613  SAMN04562533     simple   7227  Drosophila melanogaster
# 2526614  SAMN04562532     simple   7227  Drosophila melanogaster
#
#                SampleName g1k_pop_code source g1k_analysis_group Subject_ID  \
# 2483169           TM6-lab          NaN    NaN                NaN        NaN
# 2526521     CyO-TM3-24759          NaN    NaN                NaN        NaN
# 2526522      CyO-TM3-3251          NaN    NaN                NaN        NaN
# 2526523     CyO-TM3-38418          NaN    NaN                NaN        NaN
# 2526524       CyO-TM3-504          NaN    NaN                NaN        NaN
# 2526525  CyO-TM3-mp-22239          NaN    NaN                NaN        NaN
# 2526600           TM3-120          NaN    NaN                NaN        NaN
# 2526601          TM3-1614          NaN    NaN                NaN        NaN
# 2526602          TM3-1679          NaN    NaN                NaN        NaN
# 2526603          TM3-2053          NaN    NaN                NaN        NaN
# 2526604          TM3-2098          NaN    NaN                NaN        NaN
# 2526605          TM3-2198          NaN    NaN                NaN        NaN
# 2526606          TM3-2485          NaN    NaN                NaN        NaN
# 2526607           TM3-500          NaN    NaN                NaN        NaN
# 2526608          TM3-5457          NaN    NaN                NaN        NaN
# 2526609           TM3-560          NaN    NaN                NaN        NaN
# 2526610          TM3-8852          NaN    NaN                NaN        NaN
# 2526611          TM3-9013          NaN    NaN                NaN        NaN
# 2526612          TM6B-120          NaN    NaN                NaN        NaN
# 2526613         TM6B-2188          NaN    NaN                NaN        NaN
# 2526614       TM6B-mp-587          NaN    NaN                NaN        NaN
#
#                             Sex Disease Tumor Affection_Status Analyte_Type  \
# 2483169                    male     NaN    no              NaN          NaN
# 2526521                    male     NaN    no              NaN          NaN
# 2526522                    male     NaN    no              NaN          NaN
# 2526523                    male     NaN    no              NaN          NaN
# 2526524                    male     NaN    no              NaN          NaN
# 2526525  pooled male and female     NaN    no              NaN          NaN
# 2526600                    male     NaN    no              NaN          NaN
# 2526601                    male     NaN    no              NaN          NaN
# 2526602                    male     NaN    no              NaN          NaN
# 2526603                    male     NaN    no              NaN          NaN
# 2526604                    male     NaN    no              NaN          NaN
# 2526605                    male     NaN    no              NaN          NaN
# 2526606                    male     NaN    no              NaN          NaN
# 2526607                    male     NaN    no              NaN          NaN
# 2526608                    male     NaN    no              NaN          NaN
# 2526609                    male     NaN    no              NaN          NaN
# 2526610                    male     NaN    no              NaN          NaN
# 2526611                    male     NaN    no              NaN          NaN
# 2526612                    male     NaN    no              NaN          NaN
# 2526613                    male     NaN    no              NaN          NaN
# 2526614  pooled male and female     NaN    no              NaN          NaN
#
#         Histological_Type Body_Site                              CenterName  \
# 2483169               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526521               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526522               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526523               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526524               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526525               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526600               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526601               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526602               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526603               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526604               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526605               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526606               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526607               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526608               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526609               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526610               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526611               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526612               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526613               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
# 2526614               NaN       NaN  STOWERS INSTITUTE FOR MEDICAL RESEARCH
#
#         Submission dbgap_study_accession Consent  \
# 2483169  SRA393358                   NaN  public
# 2526521  SRA393358                   NaN  public
# 2526522  SRA393358                   NaN  public
# 2526523  SRA393358                   NaN  public
# 2526524  SRA393358                   NaN  public
# 2526525  SRA393358                   NaN  public
# 2526600  SRA393358                   NaN  public
# 2526601  SRA393358                   NaN  public
# 2526602  SRA393358                   NaN  public
# 2526603  SRA393358                   NaN  public
# 2526604  SRA393358                   NaN  public
# 2526605  SRA393358                   NaN  public
# 2526606  SRA393358                   NaN  public
# 2526607  SRA393358                   NaN  public
# 2526608  SRA393358                   NaN  public
# 2526609  SRA393358                   NaN  public
# 2526610  SRA393358                   NaN  public
# 2526611  SRA393358                   NaN  public
# 2526612  SRA393358                   NaN  public
# 2526613  SRA393358                   NaN  public
# 2526614  SRA393358                   NaN  public
#
#                                   RunHash                          ReadHash
# 2483169  C326BEAC0B99C5773AD0D95D493FE20A  C245C1DA0B1E58BE849B8B9CD1052D84
# 2526521  1AA25CA1170DE7D41636D896D78DC690  C4C3D10727F466D48B4E623F74F7027C
# 2526522  140F93444C0D3A80228C6D6180F36E1E  11AA2460706F193FC938143F2701E6EC
# 2526523  33172E09A551D2A3A7DCBC380491C513  1B66F0E24FFDD9F7D89A32DD187BBD12
# 2526524  F6B7B76FB0AA622353CF2C7A3C5FDADE  2CD6C85846D1102B6301F4B128F52C5A
# 2526525  F27E5FE642A20CEC7941C3F93EE58AF8  FECF114C8023B351F33B93781480EFC4
# 2526600  FBB53AE85FCAB70BCB5EAF8FA387687B  E0D8DD73D5E9E8BF6373F313D0FA5946
# 2526601  7048EA0D8B31B2FC104239B4D7B970E1  C86AE95AFFEEC9753F75B9F7209A8306
# 2526602  F27E5FE642A20CEC7941C3F93EE58AF8  FECF114C8023B351F33B93781480EFC4
# 2526603  6605D8305CA8800A8B2B82E569D4FF5A  93BF226A4401AEB46F51319679DCA3C3
# 2526604  F22322034F59D56EEEBAD2DBEFE27190  C66CBA64A7F490B799D5556A92B535A7
# 2526605  04376D4F65EC67D8B8140C30E1738255  7312F414137D59EA696D6A108F33E0FC
# 2526606  59E77463DF16C420E6F439392DFC867A  F135B77ECDC57BF907B65626B390DA42
# 2526607  DE662B2F46291D0DC6746F54789126B7  7FD5CEA2E321D28D97CA99C650F618C6
# 2526608  EBFC11772276A4E312C5F7BE0D210145  01A206F868D174D2B0E2BA4DF195B54E
# 2526609  F29C69DE45087AAF52874C06FC6E0BBE  ED63234C7C1A3E52D62E157E95AAEB78
# 2526610  F7A5672A612C36FB5CE3E83991ABE1EB  0396D5A4491693778587316456029188
# 2526611  969D4B9F67EF3577E08747B9DA9E8FD7  B321B650DD3C356087B3705C46058D14
# 2526612  88B7E67A5E06E5BD8CC613B24AB2DED6  B4E7F391255BF662D06DC3860709DFA3
# 2526613  B05DE26294093A9BE208F059B81C0DA6  A8765AD1C6BF5CC6CF3225EB795E2763
# 2526614  7C4E9EEF4B64BE4537A4BE53D4769FA1  F41FB1776578B4EAC10DD2DD8B974650

# %%
foo = pmcData.iloc[1:77731]

foo.loc[:,'dataset_date'] = ds_date
foo.loc[:,'hardware'] = hardware
foo.loc[:,'library_type'] = lib_type
foo.loc[:,'species'] = species
foo.loc[:,'throughput'] = tput
foo.loc[:,'avg_readLength'] = readLength
foo.loc[:,'access_restrictions'] = access

foo
# Out:
# /Users/niko/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /Users/niko/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
#                    journal      pmc_ID    accession converted_accession  \
# 1      Alzheimers_Res_Ther  PMC3706879     GSE45534            GSE45534
# 2      Alzheimers_Res_Ther  PMC4255636      GSE5281             GSE5281
# 3      Alzheimers_Res_Ther  PMC4731966     GSE67036            GSE67036
# 4      Alzheimers_Res_Ther  PMC4731966      GSE1297             GSE1297
# 5      Alzheimers_Res_Ther  PMC4731966     GSE48350            GSE48350
# ...                    ...         ...          ...                 ...
# 77726        G3__Bethesda_  PMC5873915    ERP020955                 NaN
# 77727        G3__Bethesda_  PMC5873901    SRP109316           SRP109316
# 77728        G3__Bethesda_  PMC5873907  PRJNA413446           SRP123654
# 77729        G3__Bethesda_  PMC5873907  PRJNA315473           SRP072215
# 77730        G3__Bethesda_  PMC5873922  PRJNA419238           SRP125651
#
#       repository  pmc_date         dataset_date                 hardware  \
# 1            GEO      2013         Sep 28, 2000              SAGE NlaIII
# 2            GEO      2014         May 25, 2004  in situ oligonucleotide
# 3            GEO      2016         Nov 07, 2003  in situ oligonucleotide
# 4            GEO      2016         May 06, 2013  in situ oligonucleotide
# 5            GEO      2016         Mar 11, 2002  in situ oligonucleotide
# ...          ...       ...                  ...                      ...
# 77726        NaN      2018                  NaN                      NaN
# 77727        SRA      2018         Mar 16, 2009  in situ oligonucleotide
# 77728        SRA      2018                  NaN                      NaN
# 77729        SRA      2018  2018-03-13 01:47:12           Illumina MiSeq
# 77730        SRA      2018  2018-03-13 01:47:12           Illumina MiSeq
#
#       library_type               species throughput avg_readLength  \
# 1          MISSING          Homo sapiens    MISSING        MISSING
# 2          MISSING          Mus musculus    MISSING        MISSING
# 3          MISSING          Homo sapiens    MISSING        MISSING
# 4          MISSING     Rattus norvegicus    MISSING        MISSING
# 5          MISSING          Homo sapiens    MISSING        MISSING
# ...            ...                   ...        ...            ...
# 77726      MISSING                   NaN    MISSING        MISSING
# 77727      MISSING          Homo sapiens    MISSING        MISSING
# 77728          NaN                   NaN        NaN            NaN
# 77729     AMPLICON  human gut metagenome   15187858            602
# 77730     AMPLICON  human gut metagenome   15187858            602
#
#       access_restrictions
# 1                 MISSING
# 2                 MISSING
# 3                 MISSING
# 4                 MISSING
# 5                 MISSING
# ...                   ...
# 77726             MISSING
# 77727             MISSING
# 77728                 NaN
# 77729              public
# 77730              public
#
# [77730 rows x 13 columns]

# %%
pmcData.loc[:,'dataset_date'] = ds_date
pmcData.loc[:,'hardware'] = hardware
pmcData.loc[:,'library_type'] = lib_type
pmcData.loc[:,'species'] = species
pmcData.loc[:,'throughput'] = tput
pmcData.loc[:,'avg_readLength'] = readLength
pmcData.loc[:,'access_restrictions'] = access


pmcData
# Out:
#                 journal      pmc_ID    accession         converted_accession  \
# 1   Alzheimers_Res_Ther  PMC3706879     GSE45534                    GSE45534
# 2   Alzheimers_Res_Ther  PMC4255636      GSE5281                     GSE5281
# 3   Alzheimers_Res_Ther  PMC4731966     GSE67036                    GSE67036
# 4   Alzheimers_Res_Ther  PMC4731966      GSE1297                     GSE1297
# 5   Alzheimers_Res_Ther  PMC4731966     GSE48350                    GSE48350
# 6   Alzheimers_Res_Ther  PMC4731966     GSE36980                    GSE36980
# 7   Alzheimers_Res_Ther  PMC4731966     GSE12679                    GSE12679
# 8   Alzheimers_Res_Ther  PMC4731966     GSE12293                    GSE12293
# 9   Alzheimers_Res_Ther  PMC4731966     GSE46871                    GSE46871
# 10  Alzheimers_Res_Ther  PMC5513091     GSE93678                    GSE93678
# 11  Alzheimers_Res_Ther  PMC5819208     GSE44772                    GSE44772
# 12  Alzheimers_Res_Ther  PMC5819208     GSE44771                    GSE44771
# 13  Alzheimers_Res_Ther  PMC6015462     GSE60862                    GSE60862
# 14  Alzheimers_Res_Ther  PMC6015462      GSE5281                     GSE5281
# 15  Alzheimers_Res_Ther  PMC6015462     GSE29378                    GSE29378
# 16  Alzheimers_Res_Ther  PMC6015462     GSE36980                    GSE36980
# 17  Alzheimers_Res_Ther  PMC6015462     GSE48350                    GSE48350
# 18  Alzheimers_Res_Ther  PMC6015462      GSE9566                     GSE9566
# 19          Biol_Direct  PMC2928186      GSE2361                     GSE2361
# 20          Biol_Direct  PMC2928186       GSE952                      GSE952
# 21          Biol_Direct  PMC1500996         GPL4              GSE14;GSE15309
# 22          Biol_Direct  PMC1634740       GDS422                         NaN
# 23          Biol_Direct  PMC1634740       GDS596                         NaN
# 24          Biol_Direct  PMC1634740       GDS181                       GSE96
# 25          Biol_Direct  PMC1634740       GSM763                         NaN
# 26          Biol_Direct  PMC1634740       GSM676                         NaN
# 27          Biol_Direct  PMC1634740       GSM761                         NaN
# 28          Biol_Direct  PMC1634740       GSM695                         NaN
# 29          Biol_Direct  PMC1634740       GSM786                         NaN
# 30          Biol_Direct  PMC1634740      GSM1499                         NaN
# ..                  ...         ...          ...                         ...
# 70          Biol_Direct  PMC3937023    SRP028846                   SRP028846
# 71          Biol_Direct  PMC3937023     GSE50858                    GSE50858
# 72          Biol_Direct  PMC4022013    GSM722763           GSE29184;GSE29218
# 73          Biol_Direct  PMC4022013    GSM722762           GSE29184;GSE29218
# 74          Biol_Direct  PMC4022013    GSM722759           GSE29184;GSE29218
# 75          Biol_Direct  PMC4022013    GSM722760           GSE29184;GSE29218
# 76          Biol_Direct  PMC4022013    GSM851275           GSE29184;GSE29218
# 77          Biol_Direct  PMC5093996     GSE26854                    GSE26854
# 78          Biol_Direct  PMC5093996     GSE32527                    GSE32527
# 79          Biol_Direct  PMC5093996  PRJNA271310                   SRP051610
# 80          Biol_Direct  PMC4094694    GSM765405  GSE26284;GSE30567;GSE49417
# 81          Biol_Direct  PMC3655853  PRJNA189432                         NaN
# 82          Biol_Direct  PMC3655853  PRJNA189433                         NaN
# 83          Biol_Direct  PMC4214606    SRX112027                   SRP009872
# 84          Biol_Direct  PMC4214606    SRX113068                   SRP009872
# 85          Biol_Direct  PMC4214606    SRX112904                   SRP009872
# 86          Biol_Direct  PMC4214606    SRX115899                   SRP010319
# 87          Biol_Direct  PMC4214606  PRJNA214746                         NaN
# 88          Biol_Direct  PMC4214606   SRR1216390                   SRP018536
# 89          Biol_Direct  PMC4214606    SRX099247                   SRP007299
# 90          Biol_Direct  PMC4214606    SRX101205                   SRP007299
# 91          Biol_Direct  PMC4214606    SRX101272                   SRP007299
# 92          Biol_Direct  PMC4214606    SRX101273                   SRP007299
# 93          Biol_Direct  PMC4214606    SRX101274                   SRP007299
# 94          Biol_Direct  PMC4214606    SRX101275                   SRP007299
# 95          Biol_Direct  PMC4214606    SRX103458                   SRP007299
# 96          Biol_Direct  PMC4214606    SRX101672                   SRP007299
# 97          Biol_Direct  PMC4214606    SRX092157                   SRP007299
# 98          Biol_Direct  PMC4214606    SRX092159                   SRP007299
# 99          Biol_Direct  PMC4214606    SRX092158                   SRP007299
#
#    repository         dataset_date                      hardware library_type  \
# 1         GEO         May 25, 2004       in situ oligonucleotide      MISSING
# 2         GEO         Nov 07, 2003       in situ oligonucleotide      MISSING
# 3         GEO         May 06, 2013       in situ oligonucleotide      MISSING
# 4         GEO         Mar 11, 2002       in situ oligonucleotide      MISSING
# 5         GEO         Nov 07, 2003       in situ oligonucleotide      MISSING
# 6         GEO                  NaN                           NaN      MISSING
# 7         GEO         Nov 07, 2003       in situ oligonucleotide      MISSING
# 8         GEO         Nov 07, 2003       in situ oligonucleotide      MISSING
# 9         GEO                  NaN                           NaN      MISSING
# 10        GEO         Apr 16, 2013    high-throughput sequencing      MISSING
# 11        GEO                  NaN                           NaN      MISSING
# 12        GEO                  NaN                           NaN      MISSING
# 13        GEO                  NaN                           NaN      MISSING
# 14        GEO         Nov 07, 2003       in situ oligonucleotide      MISSING
# 15        GEO         Jun 10, 2008         oligonucleotide beads      MISSING
# 16        GEO                  NaN                           NaN      MISSING
# 17        GEO         Nov 07, 2003       in situ oligonucleotide      MISSING
# 18        GEO         May 25, 2004       in situ oligonucleotide      MISSING
# 19        GEO         Mar 11, 2002       in situ oligonucleotide      MISSING
# 20        GEO         Mar 11, 2002       in situ oligonucleotide      MISSING
# 21        GEO         Sep 28, 2000                   SAGE NlaIII      MISSING
# 22        NaN                  NaN                           NaN          NaN
# 23        NaN                  NaN                           NaN          NaN
# 24        GEO         Mar 11, 2002       in situ oligonucleotide      MISSING
# 25        NaN                  NaN                           NaN          NaN
# 26        NaN                  NaN                           NaN          NaN
# 27        NaN                  NaN                           NaN          NaN
# 28        NaN                  NaN                           NaN          NaN
# 29        NaN                  NaN                           NaN          NaN
# 30        NaN                  NaN                           NaN          NaN
# ..        ...                  ...                           ...          ...
# 70        SRA  2013-08-26 12:33:09    AB 5500xl Genetic Analyzer      RNA-Seq
# 71        GEO         Dec 05, 2007       in situ oligonucleotide      MISSING
# 72        GEO         Feb 02, 2011    high-throughput sequencing      MISSING
# 73        GEO         Feb 02, 2011    high-throughput sequencing      MISSING
# 74        GEO         Feb 02, 2011    high-throughput sequencing      MISSING
# 75        GEO         Feb 02, 2011    high-throughput sequencing      MISSING
# 76        GEO         Feb 02, 2011    high-throughput sequencing      MISSING
# 77        GEO         Mar 11, 2010              spotted DNA/cDNA      MISSING
# 78        GEO         Dec 05, 2007       in situ oligonucleotide      MISSING
# 79        SRA  2015-12-30 00:00:00           Illumina HiSeq 2000      RNA-Seq
# 80        GEO         Sep 29, 2010    high-throughput sequencing      MISSING
# 81        NaN                  NaN                           NaN          NaN
# 82        NaN                  NaN                           NaN          NaN
# 83        SRA  2011-12-23 15:10:42  Illumina Genome Analyzer IIx          WGS
# 84        SRA  2011-12-23 15:10:42  Illumina Genome Analyzer IIx          WGS
# 85        SRA  2011-12-23 15:10:42  Illumina Genome Analyzer IIx          WGS
# 86        SRA  2012-03-30 10:56:03           Illumina HiSeq 2000          WXS
# 87        NaN                  NaN                           NaN          NaN
# 88        SRA  2013-03-12 18:43:06               Ion Torrent PGM          WGS
# 89        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx      RNA-Seq
# 90        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx      RNA-Seq
# 91        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx      RNA-Seq
# 92        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx      RNA-Seq
# 93        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx      RNA-Seq
# 94        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx      RNA-Seq
# 95        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx      RNA-Seq
# 96        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx      RNA-Seq
# 97        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx      RNA-Seq
# 98        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx      RNA-Seq
# 99        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx      RNA-Seq
#
#               species   throughput avg_readLength access_restrictions
# 1        Mus musculus      MISSING        MISSING             MISSING
# 2        Homo sapiens      MISSING        MISSING             MISSING
# 3   Rattus norvegicus      MISSING        MISSING             MISSING
# 4        Homo sapiens      MISSING        MISSING             MISSING
# 5        Homo sapiens      MISSING        MISSING             MISSING
# 6                 NaN      MISSING        MISSING             MISSING
# 7        Homo sapiens      MISSING        MISSING             MISSING
# 8        Homo sapiens      MISSING        MISSING             MISSING
# 9                 NaN      MISSING        MISSING             MISSING
# 10       Mus musculus      MISSING        MISSING             MISSING
# 11                NaN      MISSING        MISSING             MISSING
# 12                NaN      MISSING        MISSING             MISSING
# 13                NaN      MISSING        MISSING             MISSING
# 14       Homo sapiens      MISSING        MISSING             MISSING
# 15       Homo sapiens      MISSING        MISSING             MISSING
# 16                NaN      MISSING        MISSING             MISSING
# 17       Homo sapiens      MISSING        MISSING             MISSING
# 18       Mus musculus      MISSING        MISSING             MISSING
# 19       Homo sapiens      MISSING        MISSING             MISSING
# 20  Rattus norvegicus      MISSING        MISSING             MISSING
# 21       Homo sapiens      MISSING        MISSING             MISSING
# 22                NaN          NaN            NaN                 NaN
# 23                NaN          NaN            NaN                 NaN
# 24       Homo sapiens      MISSING        MISSING             MISSING
# 25                NaN          NaN            NaN                 NaN
# 26                NaN          NaN            NaN                 NaN
# 27                NaN          NaN            NaN                 NaN
# 28                NaN          NaN            NaN                 NaN
# 29                NaN          NaN            NaN                 NaN
# 30                NaN          NaN            NaN                 NaN
# ..                ...          ...            ...                 ...
# 70       Homo sapiens   7432957350             50              public
# 71       Homo sapiens      MISSING        MISSING             MISSING
# 72       Mus musculus      MISSING        MISSING             MISSING
# 73       Mus musculus      MISSING        MISSING             MISSING
# 74       Mus musculus      MISSING        MISSING             MISSING
# 75       Mus musculus      MISSING        MISSING             MISSING
# 76       Mus musculus      MISSING        MISSING             MISSING
# 77         Sus scrofa      MISSING        MISSING             MISSING
# 78       Homo sapiens      MISSING        MISSING             MISSING
# 79         Sus scrofa   6391529874            200              public
# 80       Homo sapiens      MISSING        MISSING             MISSING
# 81                NaN          NaN            NaN                 NaN
# 82                NaN          NaN            NaN                 NaN
# 83     Macaca mulatta   2639501215            150              public
# 84     Macaca mulatta   2639501215            150              public
# 85     Macaca mulatta   2639501215            150              public
# 86     Macaca mulatta  17664847480            202              public
# 87                NaN          NaN            NaN                 NaN
# 88     Macaca mulatta     15973886            118              public
# 89     Macaca mulatta   1150004184             76              public
# 90     Macaca mulatta   1150004184             76              public
# 91     Macaca mulatta   1150004184             76              public
# 92     Macaca mulatta   1150004184             76              public
# 93     Macaca mulatta   1150004184             76              public
# 94     Macaca mulatta   1150004184             76              public
# 95     Macaca mulatta   1150004184             76              public
# 96     Macaca mulatta   1150004184             76              public
# 97     Macaca mulatta   1150004184             76              public
# 98     Macaca mulatta   1150004184             76              public
# 99     Macaca mulatta   1150004184             76              public
#
# [99 rows x 12 columns]

# %%
pd.set_option('display.min_rows', 100)
pmcData
# Out:
#                 journal      pmc_ID    accession         converted_accession  \
# 1   Alzheimers_Res_Ther  PMC3706879     GSE45534                    GSE45534
# 2   Alzheimers_Res_Ther  PMC4255636      GSE5281                     GSE5281
# 3   Alzheimers_Res_Ther  PMC4731966     GSE67036                    GSE67036
# 4   Alzheimers_Res_Ther  PMC4731966      GSE1297                     GSE1297
# 5   Alzheimers_Res_Ther  PMC4731966     GSE48350                    GSE48350
# 6   Alzheimers_Res_Ther  PMC4731966     GSE36980                    GSE36980
# 7   Alzheimers_Res_Ther  PMC4731966     GSE12679                    GSE12679
# 8   Alzheimers_Res_Ther  PMC4731966     GSE12293                    GSE12293
# 9   Alzheimers_Res_Ther  PMC4731966     GSE46871                    GSE46871
# 10  Alzheimers_Res_Ther  PMC5513091     GSE93678                    GSE93678
# 11  Alzheimers_Res_Ther  PMC5819208     GSE44772                    GSE44772
# 12  Alzheimers_Res_Ther  PMC5819208     GSE44771                    GSE44771
# 13  Alzheimers_Res_Ther  PMC6015462     GSE60862                    GSE60862
# 14  Alzheimers_Res_Ther  PMC6015462      GSE5281                     GSE5281
# 15  Alzheimers_Res_Ther  PMC6015462     GSE29378                    GSE29378
# 16  Alzheimers_Res_Ther  PMC6015462     GSE36980                    GSE36980
# 17  Alzheimers_Res_Ther  PMC6015462     GSE48350                    GSE48350
# 18  Alzheimers_Res_Ther  PMC6015462      GSE9566                     GSE9566
# 19          Biol_Direct  PMC2928186      GSE2361                     GSE2361
# 20          Biol_Direct  PMC2928186       GSE952                      GSE952
# 21          Biol_Direct  PMC1500996         GPL4              GSE14;GSE15309
# 22          Biol_Direct  PMC1634740       GDS422                         NaN
# 23          Biol_Direct  PMC1634740       GDS596                         NaN
# 24          Biol_Direct  PMC1634740       GDS181                       GSE96
# 25          Biol_Direct  PMC1634740       GSM763                         NaN
# 26          Biol_Direct  PMC1634740       GSM676                         NaN
# 27          Biol_Direct  PMC1634740       GSM761                         NaN
# 28          Biol_Direct  PMC1634740       GSM695                         NaN
# 29          Biol_Direct  PMC1634740       GSM786                         NaN
# 30          Biol_Direct  PMC1634740      GSM1499                         NaN
# ..                  ...         ...          ...                         ...
# 70          Biol_Direct  PMC3937023    SRP028846                   SRP028846
# 71          Biol_Direct  PMC3937023     GSE50858                    GSE50858
# 72          Biol_Direct  PMC4022013    GSM722763           GSE29184;GSE29218
# 73          Biol_Direct  PMC4022013    GSM722762           GSE29184;GSE29218
# 74          Biol_Direct  PMC4022013    GSM722759           GSE29184;GSE29218
# 75          Biol_Direct  PMC4022013    GSM722760           GSE29184;GSE29218
# 76          Biol_Direct  PMC4022013    GSM851275           GSE29184;GSE29218
# 77          Biol_Direct  PMC5093996     GSE26854                    GSE26854
# 78          Biol_Direct  PMC5093996     GSE32527                    GSE32527
# 79          Biol_Direct  PMC5093996  PRJNA271310                   SRP051610
# 80          Biol_Direct  PMC4094694    GSM765405  GSE26284;GSE30567;GSE49417
# 81          Biol_Direct  PMC3655853  PRJNA189432                         NaN
# 82          Biol_Direct  PMC3655853  PRJNA189433                         NaN
# 83          Biol_Direct  PMC4214606    SRX112027                   SRP009872
# 84          Biol_Direct  PMC4214606    SRX113068                   SRP009872
# 85          Biol_Direct  PMC4214606    SRX112904                   SRP009872
# 86          Biol_Direct  PMC4214606    SRX115899                   SRP010319
# 87          Biol_Direct  PMC4214606  PRJNA214746                         NaN
# 88          Biol_Direct  PMC4214606   SRR1216390                   SRP018536
# 89          Biol_Direct  PMC4214606    SRX099247                   SRP007299
# 90          Biol_Direct  PMC4214606    SRX101205                   SRP007299
# 91          Biol_Direct  PMC4214606    SRX101272                   SRP007299
# 92          Biol_Direct  PMC4214606    SRX101273                   SRP007299
# 93          Biol_Direct  PMC4214606    SRX101274                   SRP007299
# 94          Biol_Direct  PMC4214606    SRX101275                   SRP007299
# 95          Biol_Direct  PMC4214606    SRX103458                   SRP007299
# 96          Biol_Direct  PMC4214606    SRX101672                   SRP007299
# 97          Biol_Direct  PMC4214606    SRX092157                   SRP007299
# 98          Biol_Direct  PMC4214606    SRX092159                   SRP007299
# 99          Biol_Direct  PMC4214606    SRX092158                   SRP007299
#
#    repository         dataset_date                      hardware  \
# 1         GEO         May 25, 2004       in situ oligonucleotide
# 2         GEO         Nov 07, 2003       in situ oligonucleotide
# 3         GEO         May 06, 2013       in situ oligonucleotide
# 4         GEO         Mar 11, 2002       in situ oligonucleotide
# 5         GEO         Nov 07, 2003       in situ oligonucleotide
# 6         GEO                  NaN                           NaN
# 7         GEO         Nov 07, 2003       in situ oligonucleotide
# 8         GEO         Nov 07, 2003       in situ oligonucleotide
# 9         GEO                  NaN                           NaN
# 10        GEO         Apr 16, 2013    high-throughput sequencing
# 11        GEO                  NaN                           NaN
# 12        GEO                  NaN                           NaN
# 13        GEO                  NaN                           NaN
# 14        GEO         Nov 07, 2003       in situ oligonucleotide
# 15        GEO         Jun 10, 2008         oligonucleotide beads
# 16        GEO                  NaN                           NaN
# 17        GEO         Nov 07, 2003       in situ oligonucleotide
# 18        GEO         May 25, 2004       in situ oligonucleotide
# 19        GEO         Mar 11, 2002       in situ oligonucleotide
# 20        GEO         Mar 11, 2002       in situ oligonucleotide
# 21        GEO         Sep 28, 2000                   SAGE NlaIII
# 22        NaN                  NaN                           NaN
# 23        NaN                  NaN                           NaN
# 24        GEO         Mar 11, 2002       in situ oligonucleotide
# 25        NaN                  NaN                           NaN
# 26        NaN                  NaN                           NaN
# 27        NaN                  NaN                           NaN
# 28        NaN                  NaN                           NaN
# 29        NaN                  NaN                           NaN
# 30        NaN                  NaN                           NaN
# ..        ...                  ...                           ...
# 70        SRA  2013-08-26 12:33:09    AB 5500xl Genetic Analyzer
# 71        GEO         Dec 05, 2007       in situ oligonucleotide
# 72        GEO         Feb 02, 2011    high-throughput sequencing
# 73        GEO         Feb 02, 2011    high-throughput sequencing
# 74        GEO         Feb 02, 2011    high-throughput sequencing
# 75        GEO         Feb 02, 2011    high-throughput sequencing
# 76        GEO         Feb 02, 2011    high-throughput sequencing
# 77        GEO         Mar 11, 2010              spotted DNA/cDNA
# 78        GEO         Dec 05, 2007       in situ oligonucleotide
# 79        SRA  2015-12-30 00:00:00           Illumina HiSeq 2000
# 80        GEO         Sep 29, 2010    high-throughput sequencing
# 81        NaN                  NaN                           NaN
# 82        NaN                  NaN                           NaN
# 83        SRA  2011-12-23 15:10:42  Illumina Genome Analyzer IIx
# 84        SRA  2011-12-23 15:10:42  Illumina Genome Analyzer IIx
# 85        SRA  2011-12-23 15:10:42  Illumina Genome Analyzer IIx
# 86        SRA  2012-03-30 10:56:03           Illumina HiSeq 2000
# 87        NaN                  NaN                           NaN
# 88        SRA  2013-03-12 18:43:06               Ion Torrent PGM
# 89        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx
# 90        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx
# 91        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx
# 92        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx
# 93        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx
# 94        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx
# 95        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx
# 96        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx
# 97        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx
# 98        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx
# 99        SRA  2011-12-01 12:59:48  Illumina Genome Analyzer IIx
#
#                library_type            species  avg_thoroughput
# 1   expressionArray;RNA-Seq       Mus musculus              NaN
# 2   expressionArray;RNA-Seq       Homo sapiens              NaN
# 3   expressionArray;RNA-Seq  Rattus norvegicus              NaN
# 4   expressionArray;RNA-Seq       Homo sapiens              NaN
# 5   expressionArray;RNA-Seq       Homo sapiens              NaN
# 6   expressionArray;RNA-Seq                NaN              NaN
# 7   expressionArray;RNA-Seq       Homo sapiens              NaN
# 8   expressionArray;RNA-Seq       Homo sapiens              NaN
# 9   expressionArray;RNA-Seq                NaN              NaN
# 10  expressionArray;RNA-Seq       Mus musculus              NaN
# 11  expressionArray;RNA-Seq                NaN              NaN
# 12  expressionArray;RNA-Seq                NaN              NaN
# 13  expressionArray;RNA-Seq                NaN              NaN
# 14  expressionArray;RNA-Seq       Homo sapiens              NaN
# 15  expressionArray;RNA-Seq       Homo sapiens              NaN
# 16  expressionArray;RNA-Seq                NaN              NaN
# 17  expressionArray;RNA-Seq       Homo sapiens              NaN
# 18  expressionArray;RNA-Seq       Mus musculus              NaN
# 19  expressionArray;RNA-Seq       Homo sapiens              NaN
# 20  expressionArray;RNA-Seq  Rattus norvegicus              NaN
# 21  expressionArray;RNA-Seq       Homo sapiens              NaN
# 22                      NaN                NaN              NaN
# 23                      NaN                NaN              NaN
# 24  expressionArray;RNA-Seq       Homo sapiens              NaN
# 25                      NaN                NaN              NaN
# 26                      NaN                NaN              NaN
# 27                      NaN                NaN              NaN
# 28                      NaN                NaN              NaN
# 29                      NaN                NaN              NaN
# 30                      NaN                NaN              NaN
# ..                      ...                ...              ...
# 70                  RNA-Seq       Homo sapiens              NaN
# 71  expressionArray;RNA-Seq       Homo sapiens              NaN
# 72  expressionArray;RNA-Seq       Mus musculus              NaN
# 73  expressionArray;RNA-Seq       Mus musculus              NaN
# 74  expressionArray;RNA-Seq       Mus musculus              NaN
# 75  expressionArray;RNA-Seq       Mus musculus              NaN
# 76  expressionArray;RNA-Seq       Mus musculus              NaN
# 77  expressionArray;RNA-Seq         Sus scrofa              NaN
# 78  expressionArray;RNA-Seq       Homo sapiens              NaN
# 79                  RNA-Seq         Sus scrofa              NaN
# 80  expressionArray;RNA-Seq       Homo sapiens              NaN
# 81                      NaN                NaN              NaN
# 82                      NaN                NaN              NaN
# 83                      WGS     Macaca mulatta              NaN
# 84                      WGS     Macaca mulatta              NaN
# 85                      WGS     Macaca mulatta              NaN
# 86                      WXS     Macaca mulatta              NaN
# 87                      NaN                NaN              NaN
# 88                      WGS     Macaca mulatta              NaN
# 89                  RNA-Seq     Macaca mulatta              NaN
# 90                  RNA-Seq     Macaca mulatta              NaN
# 91                  RNA-Seq     Macaca mulatta              NaN
# 92                  RNA-Seq     Macaca mulatta              NaN
# 93                  RNA-Seq     Macaca mulatta              NaN
# 94                  RNA-Seq     Macaca mulatta              NaN
# 95                  RNA-Seq     Macaca mulatta              NaN
# 96                  RNA-Seq     Macaca mulatta              NaN
# 97                  RNA-Seq     Macaca mulatta              NaN
# 98                  RNA-Seq     Macaca mulatta              NaN
# 99                  RNA-Seq     Macaca mulatta              NaN
#
# [99 rows x 10 columns]

# %%
for i in [ds_date, hardware, lib_type, species, tput, readLength]:
    print(len(i))
# Out:
# 99
# 99
# 99
# 99
# 28
# 28

# %%
pmcData.to_csv('pmcMatrix_withTechSpecies.csv')
